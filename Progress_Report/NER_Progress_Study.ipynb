# %% [markdown]
# ### This is Owen Monroe's Notebook for IS 567 Text Mining for the Project Progress Report
# This notebook evaluates NER models and tagging, comparing the spacy NER model to my own hand-annotated data. The text data comes from downloaded files from the Hathi-Trust Digital Library. These texts are 19th Century Magazines from the publishers, The Society for the Diffusion of Useful Knowledge, the William and Robert Chambers, and the Society for the Diffusion of General and Christian Knowledge among the Chinese.

# %%
# Loading the Spacy Model

import spacy

# %%
nlp = spacy.load('en_core_web_sm')

# %%
with open("Useful_Knowledge_Texts/Clipped_Texts/Chambers_InfoForPeople_France_1835.txt", "r", encoding="utf-8") as text_file:
    text = text_file.read()

# %%
doc = nlp(text)

# %%
hand_annotated_data = []
with open("Useful_Knowledge_Annotations_iob_3/DOCUMENT-omonroe2_illinois_edu/Chambers_InfoForPeople_France_1835.txt.tsv", "r", encoding="utf-8") as iob_file:
    for line in iob_file:
        line = line.strip()
        if line:
            token, label = line.split("\t")
           
            hand_annotated_data.append((token, label))

# %%
hand_annotated_data
# Out:
# [('he', 'O'),
#  ('principal', 'O'),
#  ('mountains', 'O'),
#  ('of', 'O'),
#  ('France', 'B-GPE'),
#  ('are', 'O'),
#  (',', 'O'),
#  ('1', 'B-CARDINAL'),
#  ('.', 'O'),
#  ('The', 'O'),
#  ('Toeget', 'O'),
#  ('on', 'O'),
#  ('the', 'O'),
#  ('north', 'O'),
#  ('-', 'O'),
#  ('east', 'O'),
#  ('.', 'O'),
#  ('They', 'O'),
#  ('are', 'O'),
#  ('of', 'O'),
#  ('a', 'O'),
#  ('rounded', 'O'),
#  ('oat', 'O'),
#  ('-', 'O'),
#  ('Bne', 'O'),
#  (',', 'O'),
#  ('with', 'O'),
#  ('gentle', 'O'),
#  ('slopes', 'O'),
#  (',', 'O'),
#  ('and', 'O'),
#  ('afford', 'O'),
#  ('much', 'O'),
#  ('open', 'O'),
#  ('paa', 'O'),
#  ('-', 'O'),
#  ('turage', 'O'),
#  ('.', 'O'),
#  ('The', 'O'),
#  ('highest', 'O'),
#  ('summit', 'O'),
#  ('is', 'O'),
#  ('not', 'O'),
#  ('more', 'O'),
#  ('than', 'O'),
#  ('4500', 'B-QUANTITY'),
#  ('ftet', 'O'),
#  ('nigh', 'O'),
#  ('.', 'O'),
#  ('2', 'O'),
#  ('.', 'O'),
#  ('The', 'O'),
#  ('Jura', 'B-LOC'),
#  ('mountains', 'I-LOC'),
#  ('He', 'O'),
#  ('to', 'O'),
#  ('the', 'O'),
#  ('south', 'O'),
#  ('of', 'O'),
#  ('these', 'O'),
#  (',', 'O'),
#  ('and', 'O'),
#  ('their', 'O'),
#  ('summiu', 'O'),
#  ('rise', 'O'),
#  ('to', 'O'),
#  ('the', 'O'),
#  ('height', 'O'),
#  ('of', 'O'),
#  ('0000', 'B-QUANTITY'),
#  ('feet', 'O'),
#  ('.', 'O'),
#  ('3', 'O'),
#  ('.', 'O'),
#  ('Many', 'O'),
#  ('Alpine', 'O'),
#  ('branches', 'O'),
#  ('intersect', 'O'),
#  ('Daaphlny', 'B-GPE'),
#  ('and', 'O'),
#  ('Provence', 'B-GPE'),
#  ('.', 'O'),
#  ('In', 'O'),
#  ('the', 'O'),
#  ('ceotre', 'O'),
#  ('of', 'O'),
#  ('the', 'O'),
#  ('kingdom', 'O'),
#  ('are', 'O'),
#  (',', 'O'),
#  ('4', 'O'),
#  ('.', 'O'),
#  ('The', 'O'),
#  ('mountains', 'B-LOC'),
#  ('of', 'I-LOC'),
#  ('Auvergne', 'I-LOC'),
#  (',', 'O'),
#  ('of', 'O'),
#  ('volcamo', 'O'),
#  ('origin', 'O'),
#  (',', 'O'),
#  ('of', 'O'),
#  ('which', 'O'),
#  ('the', 'O'),
#  ('Puy', 'B-LOC'),
#  ('de', 'I-LOC'),
#  ('Dome', 'I-LOC'),
#  (',', 'O'),
#  ('the', 'O'),
#  ('Moots', 'B-LOC'),
#  ("d'Or", 'I-LOC'),
#  (',', 'O'),
#  ('and', 'O'),
#  ('the', 'O'),
#  ('Cental', 'O'),
#  (',', 'O'),
#  ('are', 'O'),
#  ('the', 'O'),
#  ('principal', 'O'),
#  ('groups', 'O'),
#  ('.', 'O'),
#  ('5', 'O'),
#  ('.', 'O'),
#  ('The', 'O'),
#  ('Cerennee', 'O'),
#  ('Be', 'O'),
#  ('to', 'O'),
#  ('the', 'O'),
#  ('south', 'O'),
#  ('-', 'O'),
#  ('east', 'O'),
#  ('of', 'O'),
#  ('the', 'O'),
#  ('range', 'O'),
#  ('last', 'O'),
#  ('mentioned', 'O'),
#  ('.', 'O'),
#  ('Their', 'O'),
#  ('highest', 'O'),
#  ('summit', 'O'),
#  ('Is', 'O'),
#  ('Mont', 'B-LOC'),
#  ('Lozcre', 'I-LOC'),
#  ('(', 'O'),
#  ('about', 'O'),
#  ('C', 'O'),
#  ('510', 'B-QUANTITY'),
#  ('Ihet', 'O'),
#  (')', 'O'),
#  ('.', 'O'),
#  ('0', 'O'),
#  ('.', 'O'),
#  ('The', 'O'),
#  ('Pyrenees', 'B-LOC'),
#  ('form', 'O'),
#  ('the', 'O'),
#  ('prlnnipai', 'O'),
#  ('part', 'O'),
#  ('of', 'O'),
#  ('the', 'O'),
#  ('boundary', 'O'),
#  ('between', 'O'),
#  ('France', 'B-GPE'),
#  ('and', 'O'),
#  ('Spain', 'B-GPE'),
#  ('.', 'O'),
#  ('These', 'O'),
#  ('moun', 'O'),
#  ('-', 'O'),
#  ('tains', 'O'),
#  ('divide', 'O'),
#  ('the', 'O'),
#  ('cou', 'O'),
#  ('.', 'O'),
#  ('utry', 'O'),
#  ('into', 'O'),
#  ('four', 'O'),
#  ('great', 'O'),
#  ('basins', 'O'),
#  (',', 'O'),
#  ('the', 'O'),
#  ('form', 'O'),
#  ('and', 'O'),
#  ('exposure', 'O'),
#  ('of', 'O'),
#  ('which', 'O'),
#  ('necessarily', 'O'),
#  ('have', 'O'),
#  ('a', 'O'),
#  ('great', 'O'),
#  ('influence', 'O'),
#  ('on', 'O'),
#  ('their', 'O'),
#  ('climate', 'O'),
#  ('and', 'O'),
#  ('productions', 'O'),
#  ('.', 'O'),
#  ('The', 'O'),
#  ('nar', 'O'),
#  ('-', 'O'),
#  ('row', 'O'),
#  ('valley', 'O'),
#  ('of', 'O'),
#  ('the', 'O'),
#  ('Rhine', 'B-LOC'),
#  ('runs', 'O'),
#  ('from', 'O'),
#  ('nortli', 'O'),
#  ('to', 'O'),
#  ('<', 'O'),
#  ('ioutIi', 'O'),
#  (',', 'O'),
#  ('while', 'O'),
#  ('the', 'O'),
#  ('open', 'O'),
#  ('basins', 'O'),
#  ('of', 'O'),
#  ('the', 'O'),
#  ('Seine', 'B-LOC'),
#  (',', 'O'),
#  ('the', 'O'),
#  ('Loire', 'B-LOC'),
#  (',', 'O'),
#  ('and', 'O'),
#  ('the', 'O'),
#  ('Garonne', 'B-LOC'),
#  (',', 'O'),
#  ('stretch', 'O'),
#  ('iu', 'O'),
#  ('a', 'O'),
#  ('north', 'O'),
#  ('-', 'O'),
#  ('weslt', 'O'),
#  ('^', 'O'),
#  ('rn', 'O'),
#  ('direction', 'O'),
#  ('.', 'O'),
#  ('The', 'O'),
#  ('Adour', 'B-LOC'),
#  ('rises', 'O'),
#  ('in', 'O'),
#  ('the', 'O'),
#  ('Pyrenees', 'B-LOC'),
#  (',', 'O'),
#  ('and', 'O'),
#  ('washes', 'O'),
#  ('the', 'O'),
#  ('walls', 'O'),
#  ('of', 'O'),
#  ('Bayonne', 'B-LOC'),
#  ('.', 'O'),
#  ('The', 'O'),
#  ('other', 'O'),
#  ('rivers', 'O'),
#  ('are', 'O'),
#  ('principally', 'O'),
#  ('tributa', 'O'),
#  ('-', 'O'),
#  ('jfes', 'O'),
#  ('.', 'O'),
#  ('The', 'O'),
#  ('Marne', 'B-LOC'),
#  ('and', 'O'),
#  ('the', 'O'),
#  ('Oise', 'B-LOC'),
#  ('fall', 'O'),
#  ('into', 'O'),
#  ('tne', 'O'),
#  ('Seine', 'B-LOC'),
#  (';', 'O'),
#  ('the', 'O'),
#  ('Allier', 'O'),
#  (',', 'O'),
#  ('the', 'O'),
#  ('Loire', 'B-LOC'),
#  (',', 'O'),
#  ('the', 'O'),
#  ('Sarthe', 'B-LOC'),
#  (',', 'O'),
#  ('and', 'O'),
#  ('the', 'O'),
#  ('Maycnne', 'B-LOC'),
#  (',', 'O'),
#  ('into', 'O'),
#  ('the', 'O'),
#  ('Loire', 'B-LOC'),
#  (';', 'O'),
#  ('the', 'O'),
#  ('Rhone', 'B-LOC'),
#  ('receives', 'O'),
#  ('the', 'O'),
#  ('Saoue', 'B-LOC'),
#  (',', 'O'),
#  ('the', 'O'),
#  ('Isire', 'B-LOC'),
#  (',', 'O'),
#  ('the', 'O'),
#  ('Durance', 'B-LOC'),
#  (',', 'O'),
#  ('the', 'O'),
#  ('Ain', 'B-LOC'),
#  (',', 'O'),
#  ('and', 'O'),
#  ('the', 'O'),
#  ('Sorgue', 'B-LOC'),
#  (';', 'O'),
#  ('the', 'O'),
#  ('Tarn', 'B-LOC'),
#  ('and', 'O'),
#  ('the', 'O'),
#  ('Dordi', 'B-LOC'),
#  ('^', 'O'),
#  ('e', 'O'),
#  ('join', 'O'),
#  ('the', 'O'),
#  ('Garonne', 'B-LOC'),
#  ('.', 'O'),
#  ('The', 'O'),
#  ('nu', 'O'),
#  ('-', 'O'),
#  ('merous', 'O'),
#  ('branches', 'O'),
#  ('of', 'O'),
#  ('these', 'O'),
#  ('rivers', 'O'),
#  ('are', 'O'),
#  ('joined', 'O'),
#  ('by', 'O'),
#  ('canals', 'B-FAC'),
#  (',', 'O'),
#  ('which', 'O'),
#  ('form', 'O'),
#  ('an', 'O'),
#  ('extensive', 'O'),
#  ('internal', 'O'),
#  ('water', 'O'),
#  ('communication', 'O'),
#  ('.', 'O'),
#  ('In', 'O'),
#  ('resprct', 'O'),
#  ('to', 'O'),
#  ('soil', 'O'),
#  (',', 'O'),
#  ('the', 'O'),
#  ('richest', 'O'),
#  ('part', 'O'),
#  ('of', 'O'),
#  ('France', 'B-GPE'),
#  ('is', 'O'),
#  ('the', 'O'),
#  ('north', 'O'),
#  ('-', 'O'),
#  ('west', 'O'),
#  ('division', 'O'),
#  (',', 'O'),
#  ('comprehending', 'O'),
#  ('the', 'O'),
#  ('provinces', 'O'),
#  ('of', 'O'),
#  ('Flanders', 'B-GPE'),
#  (',', 'O'),
#  ('Artuis', 'B-GPE'),
#  (',', 'O'),
#  ('Picardy', 'B-GPE'),
#  (',', 'O'),
#  ('Normandy', 'B-GPE'),
#  (',', 'O'),
#  ('and', 'O'),
#  ('the', 'O'),
#  ('Isle', 'B-GPE'),
#  ('of', 'I-GPE'),
#  ('France', 'I-GPE'),
#  (',', 'O'),
#  ('where', 'O'),
#  ('there', 'O'),
#  ('is', 'O'),
#  ('a', 'O'),
#  ('deep', 'O'),
#  ('rich', 'O'),
#  ('loam', 'O'),
#  (';', 'O'),
#  ('about', 'O'),
#  ('18', 'B-QUANTITY'),
#  (',', 'I-QUANTITY'),
#  ('I', 'I-QUANTITY'),
#  ('70,51', 'I-QUANTITY'),
#  ('>', 'I-QUANTITY'),
#  ('0', 'I-QUANTITY'),
#  ('acres', 'O'),
#  ('in', 'O'),
#  ('extent', 'O'),
#  ('.', 'O'),
#  ('The', 'O'),
#  ('valley', 'O'),
#  ('of', 'O'),
#  ('the', 'O'),
#  ('Ga', 'B-LOC'),
#  ('-', 'I-LOC'),
#  ('ronne', 'I-LOC'),
#  ('ia', 'O'),
#  ('composed', 'O'),
#  ('of', 'O'),
#  ('a', 'O'),
#  ('friable', 'O'),
#  ('sandy', 'O'),
#  ('loam', 'O'),
#  (',', 'O'),
#  ('with', 'O'),
#  ('a', 'O'),
#  ('calcareous', 'O'),
#  ('mixture', 'O'),
#  (',', 'O'),
#  ('and', 'O'),
#  ('moisture', 'O'),
#  ('suthcient', 'O'),
#  ('for', 'O'),
#  ('every', 'O'),
#  ('purpose', 'O'),
#  ('.', 'O'),
#  ('This', 'O'),
#  ('district', 'O'),
#  ('contains', 'O'),
#  ('7', 'B-QUANTITY'),
#  (')', 'I-QUANTITY'),
#  ('054,501', 'I-QUANTITY'),
#  ('acres', 'O'),
#  ('.', 'O'),
#  ('The', 'O'),
#  ('greet', 'O'),
#  ('valley', 'O'),
#  ('of', 'O'),
#  ('Languedoc', 'B-LOC'),
#  ('is', 'O'),
#  ('extremely', 'O'),
#  ('prolific', 'O'),
#  (',', 'O'),
#  ('though', 'O'),
#  ('the', 'O'),
#  ('toil', 'O'),
#  ('is', 'O'),
#  ('not', 'O'),
#  ('so', 'O'),
#  ('fine', 'O'),
#  ('as', 'O'),
#  ('that', 'O'),
#  ('of', 'O'),
#  ('the', 'O'),
#  ('preceding', 'O'),
#  ('districts', 'O'),
#  ('.', 'O'),
#  ('The', 'O'),
#  ('Limarne', 'B-LOC'),
#  (',', 'O'),
#  ('a', 'O'),
#  ('valley', 'O'),
#  ('of', 'O'),
#  ('Auvergne', 'B-GPE'),
#  (',', 'O'),
#  ('Is', 'O'),
#  ('considered', 'O'),
#  ('to', 'O'),
#  ('have', 'O'),
#  ('one', 'O'),
#  ('of', 'O'),
#  ('the', 'O'),
#  ('finest', 'O'),
#  ('stjils', 'O'),
#  ('in', 'O'),
#  ('the', 'O'),
#  ('world', 'O'),
#  ('.', 'O'),
#  ('It', 'O'),
#  ('con', 'O'),
#  ('-', 'O'),
#  ('atsts', 'O'),
#  ('of', 'O'),
#  ('beds', 'O'),
#  ('of', 'O'),
#  ('earth', 'O'),
#  (',', 'O'),
#  ('said', 'O'),
#  ('to', 'O'),
#  ('be', 'O'),
#  ('twenty', 'B-QUANTITY'),
#  ('feet', 'O'),
#  ('deep', 'O'),
#  (',', 'O'),
#  ('formed', 'O'),
#  ('from', 'O'),
#  ('the', 'O'),
#  ('deojmposition', 'O'),
#  ('of', 'O'),
#  ('soft', 'O'),
#  ('basalt', 'O'),
#  ('.', 'O'),
#  ('The', 'O'),
#  ('calcareous', 'O'),
#  ('and', 'O'),
#  ('chalk', 'O'),
#  ('formations', 'O'),
#  ('are', 'O'),
#  ('extensive', 'O'),
#  ('.', 'O'),
#  ('Tlie', 'O'),
#  ('chalk', 'O'),
#  ('provinces', 'B-LOC'),
#  ('are', 'O'),
#  ('unfruitful', 'O'),
#  ('in', 'O'),
#  ('grain', 'O'),
#  (',', 'O'),
#  ('but', 'O'),
#  ('the', 'O'),
#  ('genial', 'O'),
#  ('Influence', 'O'),
#  ('of', 'O'),
#  ('the', 'O'),
#  ('sun', 'O'),
#  ('allows', 'O'),
#  ('them', 'O'),
#  ('other', 'O'),
#  ('riches', 'O'),
#  ('.', 'O'),
#  ('The', 'O'),
#  ('calcarroiis', 'O'),
#  ('loam', 'O'),
#  ('on', 'O'),
#  ('the', 'O'),
#  ('borders', 'O'),
#  ('of', 'O'),
#  ('the', 'O'),
#  ('chalk', 'O'),
#  ('formation', 'O'),
#  ('is', 'O'),
#  ('more', 'O'),
#  ('productive', 'O'),
#  ('.', 'O'),
#  ('In', 'O'),
#  ('Bretagne', 'B-LOC'),
#  (',', 'O'),
#  ('Anjou', 'B-LOC'),
#  (',', 'O'),
#  ('and', 'O'),
#  ('Maine', 'B-LOC'),
#  (',', 'O'),
#  ('are', 'O'),
#  ('immense', 'O'),
#  ('heaths', 'O'),
#  ('.', 'O'),
#  ('The', 'O'),
#  ('lanite', 'O'),
#  ('$', 'O'),
#  ('are', 'O'),
#  ('J', 'O'),
#  ('^', 'O'),
#  ('xtensive', 'O'),
#  ('tracts', 'O'),
#  ('of', 'O'),
#  ('sandy', 'O'),
#  ('deserts', 'O'),
#  (',', 'O'),
#  ('producing', 'O'),
#  ('nothing', 'O'),
#  ('but', 'O'),
#  ('broom', 'O'),
#  (',', 'O'),
#  ('heath', 'O'),
#  (',', 'O'),
#  ('and', 'O'),
#  ('Junipers', 'O'),
#  ('.', 'O'),
#  ('The', 'O'),
#  ('most', 'O'),
#  ('extensive', 'O'),
#  ('are', 'O'),
#  ('the', 'O'),
#  ('landes', 'O'),
#  ('of', 'O'),
#  ('Bordeaux', 'B-LOC'),
#  (',', 'O'),
#  ('twenty', 'O'),
#  ('leagues', 'O'),
#  ('in', 'O'),
#  ('length', 'O'),
#  ('by', 'O'),
#  ('twelve', 'O'),
#  ('In', 'O'),
#  ('breadth', 'O'),
#  ('.', 'O'),
#  ('In', 'O'),
#  ('the', 'O'),
#  ('remaining', 'O'),
#  ('provinces', 'B-LOC'),
#  (',', 'O'),
#  ('gravel', 'O'),
#  (',', 'O'),
#  ('or', 'O'),
#  ('a', 'O'),
#  ('gravelly', 'O'),
#  ('sand', 'O'),
#  (',', 'O'),
#  ('is', 'O'),
#  ('the', 'O'),
#  ('predominating', 'O'),
#  ('soil', 'O'),
#  ('.', 'O'),
#  ('The', 'O'),
#  ('woods', 'O'),
#  ('and', 'O'),
#  ('forests', 'O'),
#  ('are', 'O'),
#  ('estimated', 'O'),
#  ('to', 'O'),
#  ('oover', 'O'),
#  ('a', 'O'),
#  ('space', 'O'),
#  ('of', 'O'),
#  ('10,795,000', 'O'),
#  ('acres', 'O'),
#  ('.', 'O'),
#  ('The', 'O'),
#  ('principal', 'O'),
#  ('are', 'O'),
#  ('tlioseof', 'O'),
#  ('Ardennes', 'B-GPE'),
#  (',', 'O'),
#  ('Orleans', 'B-GPE'),
#  (',', 'O'),
#  ('and', 'O'),
#  ('For', 'B-GPE'),
#  ('.', 'I-GPE'),
#  ("taincl'leau", 'I-GPE'),
#  ('.', 'O'),
#  ('The', 'O'),
#  ('northern', 'O'),
#  ('and', 'O'),
#  ('western', 'O'),
#  ('coasts', 'O'),
#  ('are', 'O'),
#  ('formed', 'O'),
#  ('iu', 'O'),
#  ('a', 'O'),
#  ('great', 'O'),
#  ('proportion', 'O'),
#  ('by', 'O'),
#  ('immense', 'O'),
#  ('downs', 'O'),
#  ('or', 'O'),
#  ('sandbanks', 'O'),
#  (',', 'O'),
#  ('and', 'O'),
#  ('where', 'O'),
#  ('the', 'O'),
#  ('shores', 'O'),
#  ('are', 'O'),
#  ('formed', 'O'),
#  ('by', 'O'),
#  ('cliffs', 'O'),
#  (',', 'O'),
#  ('they', 'O'),
#  ('are', 'O'),
#  ('seidnrii', 'O'),
#  ('bold', 'O'),
#  ('enough', 'O'),
#  ('to', 'O'),
#  ('be', 'O'),
#  ('approached', 'O'),
#  ('with', 'O'),
#  ('safety', 'O'),
#  ('.', 'O'),
#  ('The', 'O'),
#  ('harlwurs', 'O'),
#  ('are', 'O'),
#  ('therefore', 'O'),
#  ('tew', 'O'),
#  ('.', 'O'),
#  ('On', 'O'),
#  ('the', 'O'),
#  ('Mediterranean', 'B-LOC'),
#  (',', 'O'),
#  ('the', 'O'),
#  ('cout', 'O'),
#  ('of', 'O'),
#  ('Languedoc', 'B-GPE'),
#  ('is', 'O'),
#  ('very', 'O'),
#  ('dangerous', 'O'),
#  (',', 'O'),
#  ('but', 'O'),
#  ('Provence', 'B-GPE'),
#  ('abuands', 'O'),
#  ('in', 'O'),
#  ('good', 'O'),
#  ('barbourt', 'O'),
#  ('.', 'O'),
#  ('The', 'O'),
#  ('culture', 'O'),
#  (',', 'O'),
#  ('throughout', 'O'),
#  ('the', 'O'),
#  ('northern', 'O'),
#  ('half', 'O'),
#  ('of', 'O'),
#  ('the', 'O'),
#  ('kingdom', 'O'),
#  (',', 'O'),
#  ('consists', 'O'),
#  ('of', 'O'),
#  ('wheat', 'O'),
#  (',', 'O'),
#  ('barley', 'B-PRODUCT'),
#  (',', 'O'),
#  ('oats', 'B-PRODUCT'),
#  (',', 'O'),
#  ('pulsct', 'O'),
#  ('*', 'O'),
#  ('nd', 'O'),
#  ('of', 'O'),
#  ('lata', 'O'),
#  (',', 'O'),
#  ('much', 'O'),
#  ('more', 'O'),
#  ('than', 'O'),
#  ('formerlv', 'O'),
#  (',', 'O'),
#  ('of', 'O'),
#  ('poutoes', 'B-PRODUCT'),
#  (';', 'O'),
#  ('Iu', 'O'),
#  ('(', 'O'),
#  ('he', 'O'),
#  ('eoawem', 'O'),
#  ('half', 'O'),
#  (',', 'O'),
#  ('com', 'O'),
#  ('(', 'O'),
#  ('particularly', 'O'),
#  ('malie', 'O'),
#  (')', 'O'),
#  (',', 'O'),
#  ('vintf', 'O'),
#  (',', 'O'),
#  ('mtil', 'O'),
#  ('.', 'O'),
#  ('t', 'O'),
#  ('iMilMb', 'O'),
#  ('w', 'O'),
#  ('4', 'O'),
#  ('oUtm', 'O'),
#  ('.', 'O'),
#  ('Tba', 'O'),
#  ('eM', 'O'),
#  ('Um', 'O'),
#  ('parti', 'O'),
#  (',', 'O'),
#  ('baloff', 'O'),
#  ('hmtlmf', 'O'),
#  ('>', 'O'),
#  ('puts', 'O'),
#  (',', 'O'),
#  ('beiof', 'O'),
#  ('man', 'O'),
#  ('elevated', 'O'),
#  ('than', 'O'),
#  ('the', 'O'),
#  ('western', 'O'),
#  (',', 'O'),
#  ('have', 'O'),
#  ('more', 'O'),
#  ('rigorous', 'O'),
#  ('winters', 'O'),
#  ('and', 'O'),
#  ('more', 'O'),
#  ('ardent', 'O'),
#  ('summers', 'O'),
#  ('.', 'O'),
#  ('Coal', 'B-PRODUCT'),
#  ('and', 'O'),
#  ('iron', 'B-PRODUCT'),
#  ('are', 'O'),
#  ('found', 'O'),
#  ('In', 'O'),
#  ('abundance', 'O'),
#  ('.', 'O'),
#  ('The', 'O'),
#  ('most', 'O'),
#  ('common', 'O'),
#  ('fuel', 'O'),
#  ('is', 'O'),
#  ('wood', 'O'),
#  ('.', 'O'),
#  ('The', 'O'),
#  ('superficial', 'O'),
#  ('extent', 'O'),
#  ('of', 'O'),
#  ('France', 'B-GPE'),
#  ('has', 'O'),
#  ('been', 'O'),
#  ('recently', 'O'),
#  ('estimated', 'O'),
#  ('by', 'O'),
#  ('Baron', 'B-PERSON'),
#  ('Dupin', 'I-PERSON'),
#  ('at', 'O'),
#  ('53,533,430', 'B-QUANTITY'),
#  ('hecures', 'O'),
#  (',', 'O'),
#  ('or', 'O'),
#  ('139,094,000', 'B-NORP'),
#  ('English', 'O'),
#  ('acres', 'O'),
#  ('.', 'O'),
#  ('The', 'O'),
#  ('value', 'O'),
#  ('of', 'O'),
#  ('ca', 'O'),
#  ('-', 'O'),
#  ('piul', 'O'),
#  ('vested', 'O'),
#  ('in', 'O'),
#  ('agricultural', 'O'),
#  ('pursuits', 'O'),
#  ('Is', 'O'),
#  ('estimated', 'O'),
#  ('at', 'O'),
#  ('37.532,061,470', 'B-MONEY'),
#  ('francs', 'I-MONEY'),
#  (':', 'O'),
#  ('the', 'O'),
#  ('gross', 'O'),
#  ('annual', 'O'),
#  ('produce', 'O'),
#  ('at', 'O'),
#  ('4', 'B-MONEY'),
#  (',', 'I-MONEY'),
#  ('(', 'I-MONEY'),
#  ('>', 'I-MONEY'),
#  ('78,70', 'I-MONEY'),
#  ('R', 'I-MONEY'),
#  (',', 'I-MONEY'),
#  ('805', 'I-MONEY'),
#  ('francs', 'I-MONEY'),
#  (';', 'O'),
#  ('the', 'O'),
#  ('expenses', 'O'),
#  ('of', 'O'),
#  ('cultivation', 'O'),
#  ('at', 'O'),
#  ('3,334,005', 'B-MONEY'),
#  (',', 'I-MONEY'),
#  ('.', 'I-MONEY'),
#  ("'", 'I-MONEY'),
#  ('>', 'I-MONEY'),
#  ('15', 'I-MONEY'),
#  (';', 'O'),
#  ('leaving', 'O'),
#  ('a', 'O'),
#  ('profit', 'O'),
#  ('of', 'O'),
#  ('31', 'B-PERCENT'),
#  ('per', 'I-PERCENT'),
#  ('cent', 'I-PERCENT'),
#  (',', 'O'),
#  ('on', 'O'),
#  ('the', 'O'),
#  ('capital', 'O'),
#  ('.', 'O'),
#  ('The', 'O'),
#  ('produce', 'O'),
#  ('of', 'O'),
#  ('wheat', 'B-PRODUCT'),
#  ('in', 'O'),
#  ('the', 'O'),
#  ('best', 'O'),
#  ('cultivated', 'O'),
#  ('distrlcu', 'O'),
#  (',', 'O'),
#  ('and', 'O'),
#  ('on', 'O'),
#  ('the', 'O'),
#  ('best', 'O'),
#  ('soil', 'O'),
#  (',', 'O'),
#  ('hardly', 'O'),
#  ('exceeds', 'O'),
#  ('eighteen', 'B-QUANTITY'),
#  ('bushels', 'I-QUANTITY'),
#  ('per', 'O'),
#  ('acre', 'O'),
#  (':', 'O'),
#  ('an', 'O'),
#  ('English', 'O'),
#  ('farmer', 'O'),
#  ('exptcu', 'O'),
#  ('twenty', 'O'),
#  ('-', 'O'),
#  ('five', 'O'),
#  ('or', 'O'),
#  ('the', 'O'),
#  ('same', 'O'),
#  ('extent', 'O'),
#  ('.', 'O'),
#  ('In', 'O'),
#  ('1813', 'B-DATE'),
#  (',', 'O'),
#  ('the', 'O'),
#  ('number', 'O'),
#  ('of', 'O'),
#  ('horstk', 'B-PRODUCT'),
#  ('A', 'O'),
#  ('France', 'O'),
#  ('was', 'O'),
#  ('9,170,000', 'B-CARDINAL'),
#  ('(', 'O'),
#  ('but', 'O'),
#  ('in', 'O'),
#  ('1810', 'B-DATE'),
#  (',', 'O'),
#  ('the', 'O'),
#  ('horsMs', 'B-PRODUCT'),
#  ('and', 'O'),
#  ('mules', 'B-PRODUCT'),
#  ('together', 'O'),
#  ('amountad', 'O'),
#  ('only', 'O'),
#  ('to', 'O'),
#  ('1', 'O'),
#  ('}', 'O'),
#  ('657', 'O'),
#  (',', 'O'),
#  ('C', 'O'),
#  ('7', 'O'),
#  ('1', 'O'),
#  (';', 'O'),
#  ('at', 'O'),
#  ('present', 'O'),
#  ('the', 'O'),
#  ('number', 'O'),
#  ('is', 'O'),
#  ('estimated', 'O'),
#  ('at', 'O'),
#  ('2,500,000', 'B-CARDINAL'),
#  ('.', 'O'),
#  ('The', 'O'),
#  ('number', 'O'),
#  ('of', 'O'),
#  ('homed', 'O'),
#  ('cattle', 'O'),
#  ('Is', 'O'),
#  ('6,073,000', 'B-CARDINAL'),
#  ('1', 'I-CARDINAL'),
#  ('of', 'O'),
#  ('sheep', 'B-PRODUCT'),
#  (',', 'O'),
#  ('about', 'O'),
#  ('45,0', 'O'),
#  ('e', 'O'),
#  ('^', 'O'),
#  ('000', 'O'),
#  ('.', 'O'),
#  ('The', 'O'),
#  ('total', 'O'),
#  ('number', 'O'),
#  ('of', 'O'),
#  ('all', 'O'),
#  ('kinds', 'O'),
#  ('of', 'O'),
#  ('poultry', 'B-PRODUCT'),
#  ('is', 'O'),
#  ('about', 'O'),
#  ('51,600,000', 'B-CARDINAL'),
#  ('.', 'O'),
#  ('The', 'O'),
#  ('French', 'B-NORP'),
#  ('are', 'O'),
#  ('tbe', 'O'),
#  ('best', 'O'),
#  ('wine', 'B-PRODUCT'),
#  ('-', 'O'),
#  ('makers', 'O'),
#  ('in', 'O'),
#  ('the', 'O'),
#  ('world', 'O'),
#  ('.', 'O'),
#  ('The', 'O'),
#  ('Champagne', 'O'),
#  (',', 'O'),
#  ('Burgundy', 'O'),
#  (',', 'O'),
#  ('Claret', 'O'),
#  (',', 'O'),
#  ('Hermitage', 'O'),
#  (',', 'O'),
#  ('are', 'O'),
#  ('drunk', 'O'),
#  ('all', 'O'),
#  ('over', 'O'),
#  ('the', 'O'),
#  ('world', 'O'),
#  ('.', 'O'),
#  ...]

# %%
hand_annotated_tagged = [(token, label) for token, label in hand_annotated_data if label != 'O']

# %%
hand_annotated_tagged
# Out:
# [('France', 'B-GPE'),
#  ('1', 'B-CARDINAL'),
#  ('4500', 'B-QUANTITY'),
#  ('Jura', 'B-LOC'),
#  ('mountains', 'I-LOC'),
#  ('0000', 'B-QUANTITY'),
#  ('Daaphlny', 'B-GPE'),
#  ('Provence', 'B-GPE'),
#  ('mountains', 'B-LOC'),
#  ('of', 'I-LOC'),
#  ('Auvergne', 'I-LOC'),
#  ('Puy', 'B-LOC'),
#  ('de', 'I-LOC'),
#  ('Dome', 'I-LOC'),
#  ('Moots', 'B-LOC'),
#  ("d'Or", 'I-LOC'),
#  ('Mont', 'B-LOC'),
#  ('Lozcre', 'I-LOC'),
#  ('510', 'B-QUANTITY'),
#  ('Pyrenees', 'B-LOC'),
#  ('France', 'B-GPE'),
#  ('Spain', 'B-GPE'),
#  ('Rhine', 'B-LOC'),
#  ('Seine', 'B-LOC'),
#  ('Loire', 'B-LOC'),
#  ('Garonne', 'B-LOC'),
#  ('Adour', 'B-LOC'),
#  ('Pyrenees', 'B-LOC'),
#  ('Bayonne', 'B-LOC'),
#  ('Marne', 'B-LOC'),
#  ('Oise', 'B-LOC'),
#  ('Seine', 'B-LOC'),
#  ('Loire', 'B-LOC'),
#  ('Sarthe', 'B-LOC'),
#  ('Maycnne', 'B-LOC'),
#  ('Loire', 'B-LOC'),
#  ('Rhone', 'B-LOC'),
#  ('Saoue', 'B-LOC'),
#  ('Isire', 'B-LOC'),
#  ('Durance', 'B-LOC'),
#  ('Ain', 'B-LOC'),
#  ('Sorgue', 'B-LOC'),
#  ('Tarn', 'B-LOC'),
#  ('Dordi', 'B-LOC'),
#  ('Garonne', 'B-LOC'),
#  ('canals', 'B-FAC'),
#  ('France', 'B-GPE'),
#  ('Flanders', 'B-GPE'),
#  ('Artuis', 'B-GPE'),
#  ('Picardy', 'B-GPE'),
#  ('Normandy', 'B-GPE'),
#  ('Isle', 'B-GPE'),
#  ('of', 'I-GPE'),
#  ('France', 'I-GPE'),
#  ('18', 'B-QUANTITY'),
#  (',', 'I-QUANTITY'),
#  ('I', 'I-QUANTITY'),
#  ('70,51', 'I-QUANTITY'),
#  ('>', 'I-QUANTITY'),
#  ('0', 'I-QUANTITY'),
#  ('Ga', 'B-LOC'),
#  ('-', 'I-LOC'),
#  ('ronne', 'I-LOC'),
#  ('7', 'B-QUANTITY'),
#  (')', 'I-QUANTITY'),
#  ('054,501', 'I-QUANTITY'),
#  ('Languedoc', 'B-LOC'),
#  ('Limarne', 'B-LOC'),
#  ('Auvergne', 'B-GPE'),
#  ('twenty', 'B-QUANTITY'),
#  ('provinces', 'B-LOC'),
#  ('Bretagne', 'B-LOC'),
#  ('Anjou', 'B-LOC'),
#  ('Maine', 'B-LOC'),
#  ('Bordeaux', 'B-LOC'),
#  ('provinces', 'B-LOC'),
#  ('Ardennes', 'B-GPE'),
#  ('Orleans', 'B-GPE'),
#  ('For', 'B-GPE'),
#  ('.', 'I-GPE'),
#  ("taincl'leau", 'I-GPE'),
#  ('Mediterranean', 'B-LOC'),
#  ('Languedoc', 'B-GPE'),
#  ('Provence', 'B-GPE'),
#  ('barley', 'B-PRODUCT'),
#  ('oats', 'B-PRODUCT'),
#  ('poutoes', 'B-PRODUCT'),
#  ('Coal', 'B-PRODUCT'),
#  ('iron', 'B-PRODUCT'),
#  ('France', 'B-GPE'),
#  ('Baron', 'B-PERSON'),
#  ('Dupin', 'I-PERSON'),
#  ('53,533,430', 'B-QUANTITY'),
#  ('139,094,000', 'B-NORP'),
#  ('37.532,061,470', 'B-MONEY'),
#  ('francs', 'I-MONEY'),
#  ('4', 'B-MONEY'),
#  (',', 'I-MONEY'),
#  ('(', 'I-MONEY'),
#  ('>', 'I-MONEY'),
#  ('78,70', 'I-MONEY'),
#  ('R', 'I-MONEY'),
#  (',', 'I-MONEY'),
#  ('805', 'I-MONEY'),
#  ('francs', 'I-MONEY'),
#  ('3,334,005', 'B-MONEY'),
#  (',', 'I-MONEY'),
#  ('.', 'I-MONEY'),
#  ("'", 'I-MONEY'),
#  ('>', 'I-MONEY'),
#  ('15', 'I-MONEY'),
#  ('31', 'B-PERCENT'),
#  ('per', 'I-PERCENT'),
#  ('cent', 'I-PERCENT'),
#  ('wheat', 'B-PRODUCT'),
#  ('eighteen', 'B-QUANTITY'),
#  ('bushels', 'I-QUANTITY'),
#  ('1813', 'B-DATE'),
#  ('horstk', 'B-PRODUCT'),
#  ('9,170,000', 'B-CARDINAL'),
#  ('1810', 'B-DATE'),
#  ('horsMs', 'B-PRODUCT'),
#  ('mules', 'B-PRODUCT'),
#  ('2,500,000', 'B-CARDINAL'),
#  ('6,073,000', 'B-CARDINAL'),
#  ('1', 'I-CARDINAL'),
#  ('sheep', 'B-PRODUCT'),
#  ('poultry', 'B-PRODUCT'),
#  ('51,600,000', 'B-CARDINAL'),
#  ('French', 'B-NORP'),
#  ('wine', 'B-PRODUCT'),
#  ('church', 'B-NORP'),
#  ('revolution', 'B-EVENT'),
#  ('vineyards', 'B-FAC'),
#  ('brandies', 'B-PRODUCT'),
#  ('France', 'B-GPE'),
#  ('V', 'B-PRODUCT'),
#  ('ine', 'I-PRODUCT'),
#  ('brandy', 'B-PRODUCT'),
#  ('800,000,000', 'B-MONEY'),
#  ('of', 'I-MONEY'),
#  ('fianos', 'I-MONEY'),
#  ('revolntion', 'B-EVENT'),
#  ('vine', 'B-FAC'),
#  ('-', 'I-FAC'),
#  ('yard', 'I-FAC'),
#  ('M', 'B-PERSON'),
#  ('.', 'I-PERSON'),
#  ('Dupin', 'I-PERSON'),
#  ('3', 'B-QUANTITY'),
#  ('*', 'I-QUANTITY'),
#  ('01', 'I-QUANTITY'),
#  ('cat', 'B-PRODUCT'),
#  ('-', 'I-PRODUCT'),
#  ('tle', 'I-PRODUCT'),
#  ('food', 'B-PRODUCT'),
#  ('oats', 'B-PRODUCT'),
#  ('buckwheat', 'B-PRODUCT'),
#  ('rye', 'B-PRODUCT'),
#  ('chestnuts', 'B-PRODUCT'),
#  ('potatoe', 'B-PRODUCT'),
#  ('France', 'B-GPE'),
#  ('France', 'B-GPE'),
#  ('cotton', 'B-PRODUCT'),
#  ('cloths', 'B-PRODUCT'),
#  ('Sedan', 'B-LOC'),
#  ('Colbert', 'B-PERSON'),
#  ('M', 'B-PERSON'),
#  ('.', 'I-PERSON'),
#  ('Chaptal', 'I-PERSON'),
#  ('English', 'B-NORP'),
#  ('machinist', 'I-NORP'),
#  ('French', 'B-NORP'),
#  ('aruxans', 'I-NORP'),
#  ('spinning', 'B-FAC'),
#  ('mills', 'I-FAC'),
#  ('wool', 'B-PRODUCT'),
#  ('1819', 'B-DATE'),
#  ('38,000,000', 'B-QUANTITY'),
#  ('kilogrammes', 'I-QUANTITY'),
#  ('3', 'B-QUANTITY'),
#  ('|', 'I-QUANTITY'),
#  ('lbs', 'I-QUANTITY'),
#  ('1836', 'B-DATE'),
#  ('4', 'B-QUANTITY'),
#  ('^', 'I-QUANTITY'),
#  (',', 'I-QUANTITY'),
#  ('000,000', 'I-QUANTITY'),
#  ('000,000', 'B-QUANTITY'),
#  ('wool', 'B-PRODUCT'),
#  ('305,000,000', 'B-MONEY'),
#  ('francs', 'I-MONEY'),
#  ('raw', 'B-PRODUCT'),
#  ('wool', 'I-PRODUCT'),
#  ('105,000,000', 'B-QUANTITY'),
#  ('Henry', 'B-PERSON'),
#  ('IV', 'I-PERSON'),
#  ('mulberry', 'B-PRODUCT'),
#  ('.', 'I-PRODUCT'),
#  ('tree', 'I-PRODUCT'),
#  ('southern', 'B-LOC'),
#  ('provinces', 'I-LOC'),
#  ('Tours', 'B-GPE'),
#  ('silk', 'B-PRODUCT'),
#  ('furniture', 'B-PRODUCT'),
#  ('Ganges', 'B-GPE'),
#  ('Cevennes', 'B-LOC'),
#  ('silk', 'B-PRODUCT'),
#  ('stockings', 'I-PRODUCT'),
#  ('Lyons', 'B-GPE'),
#  ('silk', 'B-PRODUCT'),
#  ('Paris', 'B-GPE'),
#  ('Lyons', 'B-GPE'),
#  ('181', 'B-DATE'),
#  ('45,500', 'B-MONEY'),
#  (',', 'I-MONEY'),
#  ('(', 'I-MONEY'),
#  ('HIO', 'I-MONEY'),
#  ('francs', 'I-MONEY'),
#  ('33,000,000', 'B-QUANTITY'),
#  ('silk', 'B-PRODUCT'),
#  ('manufactured', 'B-PRODUCT'),
#  ('goods', 'I-PRODUCT'),
#  ('cotton', 'B-PRODUCT'),
#  ('France', 'B-GPE'),
#  ('Cotton', 'B-PRODUCT'),
#  ('Alsace', 'B-GPE'),
#  ('England', 'B-GPE'),
#  ('11113', 'B-DATE'),
#  ('3,000', 'B-QUANTITY'),
#  ('kilogrammes', 'I-QUANTITY'),
#  ('oitton', 'B-PRODUCT'),
#  ('cambrics', 'B-PRODUCT'),
#  ('gaiue', 'B-PRODUCT'),
#  ('aiul', 'B-PRODUCT'),
#  ('lawn', 'I-PRODUCT'),
#  ('St', 'B-GPE'),
#  ('Quentin', 'I-GPE'),
#  ('Valen', 'B-GPE'),
#  ('-', 'I-GPE'),
#  ('ciennes', 'I-GPE'),
#  ('Cambray', 'B-GPE'),
#  ('Lace', 'B-PRODUCT'),
#  ('linen', 'B-PRODUCT'),
#  ('hemp', 'B-PRODUCT'),
#  ('300,00', 'B-MONEY'),
#  ('(', 'I-MONEY'),
#  ('»', 'I-MONEY'),
#  (',', 'I-MONEY'),
#  ('000', 'I-MONEY'),
#  ('francs', 'I-MONEY'),
#  ('1814', 'B-DATE'),
#  ('100,000,000', 'B-QUANTITY'),
#  ('kilogrammes', 'I-QUANTITY'),
#  ('1825', 'B-DATE'),
#  ('180,000,000', 'B-QUANTITY'),
#  ('Paris', 'B-GPE'),
#  ('38,000,000', 'B-MONEY'),
#  ('francs', 'I-MONEY'),
#  ('Paris', 'B-GPE'),
#  ('45,075,030', 'B-CARDINAL'),
#  ('1820', 'B-DATE'),
#  ('80,031,303', 'B-CARDINAL'),
#  ('1830', 'B-DATE'),
#  ('France', 'B-GPE'),
#  ('England', 'B-GPE'),
#  ('roads', 'B-FAC'),
#  ('canals', 'B-FAC'),
#  ('roads', 'B-FAC'),
#  ('England', 'B-GPE'),
#  ('cross', 'B-FAC'),
#  ('-', 'I-FAC'),
#  ('roeds', 'I-FAC'),
#  ('roads', 'B-FAC'),
#  ('canals', 'B-FAC'),
#  ('France', 'B-GPE'),
#  ('England', 'B-GPE'),
#  ('France', 'B-GPE'),
#  ('steam', 'B-FAC'),
#  ('.', 'I-FAC'),
#  ('engines', 'I-FAC'),
#  ('steam', 'B-FAC'),
#  ('-', 'I-FAC'),
#  ('engines', 'I-FAC'),
#  ('France', 'B-GPE'),
#  ('Dupin', 'B-PERSON'),
#  ('England', 'B-GPE'),
#  ('France', 'B-GPE'),
#  ('England', 'B-GPE'),
#  ('colonies', 'B-LOC'),
#  ('1788', 'B-DATE'),
#  ('337,0', 'B-MONEY'),
#  ('tW', 'I-MONEY'),
#  (',', 'I-MONEY'),
#  ("'", 'I-MONEY'),
#  ('i', 'I-MONEY'),
#  ('00', 'I-MONEY'),
#  ('francs', 'I-MONEY'),
#  ('1834', 'B-DATE'),
#  ('50,000,000', 'B-MONEY'),
#  ('France', 'B-GPE'),
#  ('1834', 'B-DATE'),
#  ('440,543,000', 'B-MONEY'),
#  ('francs', 'I-MONEY'),
#  ('103,050,000', 'B-MONEY'),
#  ('277,486,000', 'B-MONEY'),
#  ('manufactured', 'B-PRODUCT'),
#  ('United', 'B-GPE'),
#  ('States', 'I-GPE'),
#  ('55,000,000', 'B-MONEY'),
#  ('454,801,000', 'B-MONEY'),
#  ('francs', 'I-MONEY'),
#  ('373,873,000', 'B-MONEY'),
#  ('materials', 'B-PRODUCT'),
#  ('for', 'I-PRODUCT'),
#  ('manufacture', 'I-PRODUCT'),
#  ('natural', 'B-PRODUCT'),
#  ('productions', 'I-PRODUCT'),
#  ('for', 'I-PRODUCT'),
#  ('consumption', 'I-PRODUCT'),
#  ('manufactured', 'B-PRODUCT'),
#  ('articles', 'I-PRODUCT'),
#  ('1824', 'B-DATE'),
#  ('ships', 'B-FAC'),
#  ('328,480', 'B-CARDINAL'),
#  ('28,040', 'B-CARDINAL'),
#  ('47,383', 'B-CARDINAL'),
#  ('fisheries', 'B-FAC'),
#  ('navy', 'B-NORP'),
#  ('1838', 'B-DATE'),
#  ('38', 'B-CARDINAL'),
#  ('ships', 'B-FAC'),
#  ('35', 'B-CARDINAL'),
#  ('frigates', 'B-FAC'),
#  ('8', 'B-CARDINAL'),
#  ('steam', 'B-FAC'),
#  ('186', 'B-CARDINAL'),
#  ('veasels', 'B-FAC'),
#  ('14,003', 'B-CARDINAL'),
#  ('officera', 'B-NORP'),
#  ('sailors', 'B-NORP'),
#  ('army', 'B-NORP'),
#  ('1828 am', 'B-DATE'),
#  ('233,770', 'B-CARDINAL'),
#  ('French', 'B-NORP'),
#  ('-', 'I-NORP'),
#  ('man', 'I-NORP'),
#  ('1828', 'B-DATE'),
#  ('l', 'B-MONEY'),
#  (',', 'I-MONEY'),
#  ('037', 'I-MONEY'),
#  (',', 'I-MONEY'),
#  ('iO', 'I-MONEY'),
#  ('4,4', 'I-MONEY'),
#  ('»', 'I-MONEY'),
#  ('l', 'I-MONEY'),
#  ('francs', 'I-MONEY'),
#  ('1,035,415,552', 'B-MONEY'),
#  ('franos', 'I-MONEY'),
#  ('French', 'B-EVENT'),
#  ('Revo', 'I-EVENT'),
#  ('-', 'I-EVENT'),
#  ('lution', 'I-EVENT'),
#  ('1780', 'B-DATE'),
#  ('military', 'B-NORP'),
#  ('nation', 'B-NORP'),
#  ('manufac', 'B-FAC'),
#  ('-', 'I-FAC'),
#  ('tures', 'I-FAC'),
#  ('constitution', 'B-LAW'),
#  ('1830', 'B-DATE'),
#  ('Louis', 'B-PERSON'),
#  ('Philip', 'I-PERSON'),
#  ('throne', 'B-NORP'),
#  ('three', 'B-EVENT'),
#  ('days', 'I-EVENT'),
#  ('revolu', 'B-EVENT'),
#  ('-', 'I-EVENT'),
#  ('tion', 'I-EVENT'),
#  ('Bourbons', 'B-NORP'),
#  ('house', 'B-NORP'),
#  ('of', 'I-NORP'),
#  ('Orleans', 'I-NORP'),
#  ('Louis', 'B-PERSON'),
#  ('XIV', 'I-PERSON'),
#  ('Philip', 'B-PERSON'),
#  ('Duke', 'I-PERSON'),
#  ('of', 'I-PERSON'),
#  ('Orleans', 'I-PERSON'),
#  ('France', 'B-GPE'),
#  ('Capet', 'B-PERSON'),
#  ('Dyruuty', 'I-PERSON'),
#  ('Hugh', 'B-PERSON'),
#  ('Capet', 'I-PERSON'),
#  ('987', 'B-DATE'),
#  ('900', 'B-DATE'),
#  ('Robert', 'B-PERSON'),
#  ('031', 'B-DATE'),
#  ('Henry', 'B-PERSON'),
#  ('L', 'I-PERSON'),
#  ('1080', 'B-DATE'),
#  ('Philip', 'B-PERSON'),
#  ('L', 'I-PERSON'),
#  ('1108', 'B-DATE'),
#  ('L', 'B-PERSON'),
#  ('uis', 'I-PERSON'),
#  ('IV', 'I-PERSON'),
#  ('113', 'B-DATE'),
#  ('?', 'I-DATE'),
#  ('liouis', 'B-PERSON'),
#  ('Vn', 'I-PERSON'),
#  ('Philip', 'B-PERSON'),
#  ('il', 'I-PERSON'),
#  ('.', 'I-PERSON'),
#  ('Augustus', 'B-PERSON'),
#  ('1233', 'B-DATE'),
#  ('Louis', 'B-PERSON'),
#  ('VIII', 'I-PERSON'),
#  ('1336', 'B-DATE'),
#  ('Louis', 'B-PERSON'),
#  ('IX', 'I-PERSON'),
#  ('.', 'I-PERSON'),
#  ('(', 'I-PERSON'),
#  ('the', 'I-PERSON'),
#  ('Saint', 'I-PERSON'),
#  (')', 'I-PERSON'),
#  ('1370', 'B-DATE'),
#  ('Philip', 'B-PERSON'),
#  ('III', 'I-PERSON'),
#  ('.', 'I-PERSON'),
#  ('(', 'I-PERSON'),
#  ('the', 'I-PERSON'),
#  ('Bold', 'I-PERSON'),
#  (')', 'I-PERSON'),
#  ('1285', 'B-DATE'),
#  ('Philip', 'B-PERSON'),
#  ('IV', 'I-PERSON'),
#  ('.', 'I-PERSON'),
#  ('(', 'I-PERSON'),
#  ('the', 'I-PERSON'),
#  ('Fair', 'I-PERSON'),
#  (')', 'I-PERSON'),
#  ('1314', 'B-DATE'),
#  ('Louts', 'B-PERSON'),
#  ('X', 'I-PERSON'),
#  ('.', 'I-PERSON'),
#  ('(', 'I-PERSON'),
#  ('Hutin', 'I-PERSON'),
#  (')', 'I-PERSON'),
#  ('1310', 'B-DATE'),
#  ('Philip', 'B-PERSON'),
#  ('V', 'I-PERSON'),
#  ('.', 'I-PERSON'),
#  ('(', 'I-PERSON'),
#  ('the', 'I-PERSON'),
#  ('liong', 'I-PERSON'),
#  (')', 'I-PERSON'),
#  ('1331', 'B-DATE'),
#  ('Charles', 'B-PERSON'),
#  ('IV', 'I-PERSON'),
#  ('.', 'I-PERSON'),
#  ('(', 'I-PERSON'),
#  ('the', 'I-PERSON'),
#  ('Fair', 'I-PERSON'),
#  (')', 'I-PERSON'),
#  ('133', 'B-DATE'),
#  ('a', 'I-DATE'),
#  ('—', 'I-DATE'),
#  ('3', 'I-DATE'),
#  ('Branch', 'B-PERSON'),
#  ('0', 'I-PERSON'),
#  ('/', 'I-PERSON'),
#  ('Vahitt', 'I-PERSON'),
#  ('Philip', 'I-PERSON'),
#  ('VL', 'I-PERSON'),
#  ('1350', 'B-DATE'),
#  ('John', 'B-PERSON'),
#  ('ChaHee', 'B-PERSON'),
#  ('V', 'I-PERSON'),
#  ('.', 'I-PERSON'),
#  ('(', 'I-PERSON'),
#  ('the', 'I-PERSON'),
#  ('Wise', 'I-PERSON'),
#  (')', 'I-PERSON'),
#  ('1380', 'B-DATE'),
#  ('Charles', 'B-PERSON'),
#  ('VI', 'I-PERSON'),
#  ('1433', 'B-DATE'),
#  ('Charles', 'B-PERSON'),
#  ('VIL', 'I-PERSON'),
#  ('1401', 'B-DATE'),
#  ('Louis', 'B-PERSON'),
#  ('XI', 'I-PERSON'),
#  ('1463', 'B-DATE'),
#  ('Charles', 'B-PERSON'),
#  ('VIIL', 'I-PERSON'),
#  ('1407', 'B-DATE'),
#  ('Louis', 'B-PERSON'),
#  ('XIL', 'I-PERSON'),
#  ('1515', 'B-DATE'),
#  ('Francis', 'B-PERSON'),
#  ('I', 'I-PERSON'),
#  ('1547', 'B-DATE'),
#  ('Henry', 'B-PERSON'),
#  ('IL', 'I-PERSON'),
#  ('1550', 'B-DATE'),
#  ('1560', 'B-DATE'),
#  ('Charles', 'B-PERSON'),
#  ('IX', 'I-PERSON'),
#  ('1574', 'B-DATE'),
#  ('Henry', 'B-PERSON'),
#  ('IIL', 'I-PERSON'),
#  ('1580', 'B-DATE'),
#  ('Henry', 'B-PERSON'),
#  ('IV', 'I-PERSON'),
#  ('1610', 'B-DATE'),
#  ('Louis', 'B-PERSON'),
#  ('XIIL', 'I-PERSON'),
#  ('1643', 'B-DATE'),
#  ('LoiHs', 'B-PERSON'),
#  ('XIV', 'I-PERSON'),
#  ('1715', 'B-DATE'),
#  ('Louis', 'B-PERSON'),
#  ('XV', 'I-PERSON'),
#  ('Louis', 'B-PERSON'),
#  ('XVI', 'I-PERSON'),
#  ('1793', 'B-DATE'),
#  ('Louis', 'B-PERSON'),
#  ('XVU', 'I-PERSON'),
#  ('French', 'B-NORP'),
#  ('republic', 'I-NORP'),
#  ('1703', 'B-DATE'),
#  ('1804', 'B-DATE'),
#  ('Napoleon', 'B-PERSON'),
#  ('Emperor', 'B-NORP'),
#  ('of', 'I-NORP'),
#  ('the', 'I-NORP'),
#  ('French', 'I-NORP'),
#  ('1804', 'B-DATE'),
#  ('1814', 'B-DATE'),
#  ('Louis', 'B-PERSON'),
#  ('XVIIL', 'I-PERSON'),
#  ('1814', 'B-DATE'),
#  ('1024', 'B-DATE'),
#  ('Charles', 'B-PERSON'),
#  ('1830', 'B-DATE'),
#  ('House', 'B-NORP'),
#  ('of', 'I-NORP'),
#  ('Orleans', 'I-NORP'),
#  ('Louis', 'B-PERSON'),
#  ('Philip', 'I-PERSON'),
#  ('King', 'B-NORP'),
#  ('of', 'I-NORP'),
#  ('the', 'I-NORP'),
#  ('French', 'I-NORP'),
#  ('Bourbon', 'B-NORP'),
#  ('family', 'I-NORP'),
#  ('Charles', 'B-PERSON'),
#  ('X', 'I-PERSON'),
#  ('Louis', 'B-PERSON'),
#  ('Antoine', 'I-PERSON'),
#  (',', 'I-PERSON'),
#  ('Duke', 'I-PERSON'),
#  ('of', 'I-PERSON'),
#  ('Angouldme', 'I-PERSON'),
#  ('(', 'I-PERSON'),
#  ('late', 'I-PERSON'),
#  ('dauphin', 'I-PERSON'),
#  (')', 'I-PERSON'),
#  ('August', 'B-DATE'),
#  ('6', 'I-DATE'),
#  (',', 'I-DATE'),
#  ('1775', 'I-DATE'),
#  ('Marie', 'B-PERSON'),
#  ('Therese', 'I-PERSON'),
#  ('Louie', 'B-PERSON'),
#  ('XVI', 'I-PERSON'),
#  ('Charles', 'B-PERSON'),
#  ('X', 'I-PERSON'),
#  ('.', 'I-PERSON'),
#  (',', 'I-PERSON'),
#  ('Duke', 'I-PERSON'),
#  ('of', 'I-PERSON'),
#  ('Berry', 'I-PERSON'),
#  ('Jan', 'B-DATE'),
#  ('.', 'I-DATE'),
#  ('24', 'I-DATE'),
#  (',', 'I-DATE'),
#  ('1778', 'I-DATE'),
#  ('Caroline', 'B-PERSON'),
#  (',', 'I-PERSON'),
#  ('Princess', 'I-PERSON'),
#  ('of', 'I-PERSON'),
#  ('Naples', 'I-PERSON'),
#  ('Nov', 'B-DATE'),
#  ('.', 'I-DATE'),
#  ('5', 'I-DATE'),
#  (',', 'I-DATE'),
#  ('1708', 'I-DATE'),
#  ('Louvain', 'B-PERSON'),
#  ('Feb', 'B-DATE'),
#  (',', 'I-DATE'),
#  ('14', 'I-DATE'),
#  (',', 'I-DATE'),
#  ('1820', 'I-DATE'),
#  ('Maria', 'B-PERSON'),
#  ('Louise', 'I-PERSON'),
#  ('(', 'I-PERSON'),
#  ('Mile', 'I-PERSON'),
#  ('.', 'I-PERSON'),
#  ('d', 'I-PERSON'),
#  ('*', 'I-PERSON'),
#  ('Artois', 'I-PERSON'),
#  (',', 'I-PERSON'),
#  ('Sept', 'B-DATE'),
#  ('.', 'I-DATE'),
#  ('21', 'I-DATE'),
#  (',', 'I-DATE'),
#  ('1819', 'I-DATE'),
#  ('Henry', 'B-PERSON'),
#  ('(', 'I-PERSON'),
#  ('Charles', 'I-PERSON'),
#  ('Ferdinrnd', 'I-PERSON'),
#  ('Marie', 'I-PERSON'),
#  ("DieudonnL'", 'I-PERSON'),
#  (')', 'I-PERSON'),
#  ('Duke', 'B-PERSON'),
#  ('1820', 'B-DATE'),
#  ('Charles', 'B-PERSON'),
#  ('Kiag', 'B-PERSON'),
#  ('Henry', 'I-PERSON'),
#  ('V', 'I-PERSON'),
#  ('I', 'B-PERSON'),
#  ('<', 'I-PERSON'),
#  ('ouis', 'I-PERSON'),
#  ('Philip', 'I-PERSON'),
#  ('Ferdinand', 'B-PERSON'),
#  ('PhtUp', 'I-PERSON'),
#  ('Louis', 'B-PERSON'),
#  ('Charles', 'I-PERSON'),
#  ('Henry', 'I-PERSON'),
#  ('Duke', 'B-PERSON'),
#  ('of', 'I-PERSON'),
#  ('Orleans', 'I-PERSON'),
#  ('1810', 'B-DATE')]

# %%
for i in range(len(hand_annotated_tagged)):
    token, label = hand_annotated_tagged[i]
    if label.startswith('B-'):
        label = label[2:]  # Remove "B-"
    elif label.startswith('I-'):
        label = label[2:]  # Remove "I-"
    hand_annotated_tagged[i] = (token, label)
    hand_annotated_clean = hand_annotated_tagged

# %%
print(f'Hand Annotations List number = {len(hand_annotated_clean)}')
hand_annotated_clean
# Out:
# Hand Annotations List number = 645
# [('France', 'GPE'),
#  ('1', 'CARDINAL'),
#  ('4500', 'QUANTITY'),
#  ('Jura', 'LOC'),
#  ('mountains', 'LOC'),
#  ('0000', 'QUANTITY'),
#  ('Daaphlny', 'GPE'),
#  ('Provence', 'GPE'),
#  ('mountains', 'LOC'),
#  ('of', 'LOC'),
#  ('Auvergne', 'LOC'),
#  ('Puy', 'LOC'),
#  ('de', 'LOC'),
#  ('Dome', 'LOC'),
#  ('Moots', 'LOC'),
#  ("d'Or", 'LOC'),
#  ('Mont', 'LOC'),
#  ('Lozcre', 'LOC'),
#  ('510', 'QUANTITY'),
#  ('Pyrenees', 'LOC'),
#  ('France', 'GPE'),
#  ('Spain', 'GPE'),
#  ('Rhine', 'LOC'),
#  ('Seine', 'LOC'),
#  ('Loire', 'LOC'),
#  ('Garonne', 'LOC'),
#  ('Adour', 'LOC'),
#  ('Pyrenees', 'LOC'),
#  ('Bayonne', 'LOC'),
#  ('Marne', 'LOC'),
#  ('Oise', 'LOC'),
#  ('Seine', 'LOC'),
#  ('Loire', 'LOC'),
#  ('Sarthe', 'LOC'),
#  ('Maycnne', 'LOC'),
#  ('Loire', 'LOC'),
#  ('Rhone', 'LOC'),
#  ('Saoue', 'LOC'),
#  ('Isire', 'LOC'),
#  ('Durance', 'LOC'),
#  ('Ain', 'LOC'),
#  ('Sorgue', 'LOC'),
#  ('Tarn', 'LOC'),
#  ('Dordi', 'LOC'),
#  ('Garonne', 'LOC'),
#  ('canals', 'FAC'),
#  ('France', 'GPE'),
#  ('Flanders', 'GPE'),
#  ('Artuis', 'GPE'),
#  ('Picardy', 'GPE'),
#  ('Normandy', 'GPE'),
#  ('Isle', 'GPE'),
#  ('of', 'GPE'),
#  ('France', 'GPE'),
#  ('18', 'QUANTITY'),
#  (',', 'QUANTITY'),
#  ('I', 'QUANTITY'),
#  ('70,51', 'QUANTITY'),
#  ('>', 'QUANTITY'),
#  ('0', 'QUANTITY'),
#  ('Ga', 'LOC'),
#  ('-', 'LOC'),
#  ('ronne', 'LOC'),
#  ('7', 'QUANTITY'),
#  (')', 'QUANTITY'),
#  ('054,501', 'QUANTITY'),
#  ('Languedoc', 'LOC'),
#  ('Limarne', 'LOC'),
#  ('Auvergne', 'GPE'),
#  ('twenty', 'QUANTITY'),
#  ('provinces', 'LOC'),
#  ('Bretagne', 'LOC'),
#  ('Anjou', 'LOC'),
#  ('Maine', 'LOC'),
#  ('Bordeaux', 'LOC'),
#  ('provinces', 'LOC'),
#  ('Ardennes', 'GPE'),
#  ('Orleans', 'GPE'),
#  ('For', 'GPE'),
#  ('.', 'GPE'),
#  ("taincl'leau", 'GPE'),
#  ('Mediterranean', 'LOC'),
#  ('Languedoc', 'GPE'),
#  ('Provence', 'GPE'),
#  ('barley', 'PRODUCT'),
#  ('oats', 'PRODUCT'),
#  ('poutoes', 'PRODUCT'),
#  ('Coal', 'PRODUCT'),
#  ('iron', 'PRODUCT'),
#  ('France', 'GPE'),
#  ('Baron', 'PERSON'),
#  ('Dupin', 'PERSON'),
#  ('53,533,430', 'QUANTITY'),
#  ('139,094,000', 'NORP'),
#  ('37.532,061,470', 'MONEY'),
#  ('francs', 'MONEY'),
#  ('4', 'MONEY'),
#  (',', 'MONEY'),
#  ('(', 'MONEY'),
#  ('>', 'MONEY'),
#  ('78,70', 'MONEY'),
#  ('R', 'MONEY'),
#  (',', 'MONEY'),
#  ('805', 'MONEY'),
#  ('francs', 'MONEY'),
#  ('3,334,005', 'MONEY'),
#  (',', 'MONEY'),
#  ('.', 'MONEY'),
#  ("'", 'MONEY'),
#  ('>', 'MONEY'),
#  ('15', 'MONEY'),
#  ('31', 'PERCENT'),
#  ('per', 'PERCENT'),
#  ('cent', 'PERCENT'),
#  ('wheat', 'PRODUCT'),
#  ('eighteen', 'QUANTITY'),
#  ('bushels', 'QUANTITY'),
#  ('1813', 'DATE'),
#  ('horstk', 'PRODUCT'),
#  ('9,170,000', 'CARDINAL'),
#  ('1810', 'DATE'),
#  ('horsMs', 'PRODUCT'),
#  ('mules', 'PRODUCT'),
#  ('2,500,000', 'CARDINAL'),
#  ('6,073,000', 'CARDINAL'),
#  ('1', 'CARDINAL'),
#  ('sheep', 'PRODUCT'),
#  ('poultry', 'PRODUCT'),
#  ('51,600,000', 'CARDINAL'),
#  ('French', 'NORP'),
#  ('wine', 'PRODUCT'),
#  ('church', 'NORP'),
#  ('revolution', 'EVENT'),
#  ('vineyards', 'FAC'),
#  ('brandies', 'PRODUCT'),
#  ('France', 'GPE'),
#  ('V', 'PRODUCT'),
#  ('ine', 'PRODUCT'),
#  ('brandy', 'PRODUCT'),
#  ('800,000,000', 'MONEY'),
#  ('of', 'MONEY'),
#  ('fianos', 'MONEY'),
#  ('revolntion', 'EVENT'),
#  ('vine', 'FAC'),
#  ('-', 'FAC'),
#  ('yard', 'FAC'),
#  ('M', 'PERSON'),
#  ('.', 'PERSON'),
#  ('Dupin', 'PERSON'),
#  ('3', 'QUANTITY'),
#  ('*', 'QUANTITY'),
#  ('01', 'QUANTITY'),
#  ('cat', 'PRODUCT'),
#  ('-', 'PRODUCT'),
#  ('tle', 'PRODUCT'),
#  ('food', 'PRODUCT'),
#  ('oats', 'PRODUCT'),
#  ('buckwheat', 'PRODUCT'),
#  ('rye', 'PRODUCT'),
#  ('chestnuts', 'PRODUCT'),
#  ('potatoe', 'PRODUCT'),
#  ('France', 'GPE'),
#  ('France', 'GPE'),
#  ('cotton', 'PRODUCT'),
#  ('cloths', 'PRODUCT'),
#  ('Sedan', 'LOC'),
#  ('Colbert', 'PERSON'),
#  ('M', 'PERSON'),
#  ('.', 'PERSON'),
#  ('Chaptal', 'PERSON'),
#  ('English', 'NORP'),
#  ('machinist', 'NORP'),
#  ('French', 'NORP'),
#  ('aruxans', 'NORP'),
#  ('spinning', 'FAC'),
#  ('mills', 'FAC'),
#  ('wool', 'PRODUCT'),
#  ('1819', 'DATE'),
#  ('38,000,000', 'QUANTITY'),
#  ('kilogrammes', 'QUANTITY'),
#  ('3', 'QUANTITY'),
#  ('|', 'QUANTITY'),
#  ('lbs', 'QUANTITY'),
#  ('1836', 'DATE'),
#  ('4', 'QUANTITY'),
#  ('^', 'QUANTITY'),
#  (',', 'QUANTITY'),
#  ('000,000', 'QUANTITY'),
#  ('000,000', 'QUANTITY'),
#  ('wool', 'PRODUCT'),
#  ('305,000,000', 'MONEY'),
#  ('francs', 'MONEY'),
#  ('raw', 'PRODUCT'),
#  ('wool', 'PRODUCT'),
#  ('105,000,000', 'QUANTITY'),
#  ('Henry', 'PERSON'),
#  ('IV', 'PERSON'),
#  ('mulberry', 'PRODUCT'),
#  ('.', 'PRODUCT'),
#  ('tree', 'PRODUCT'),
#  ('southern', 'LOC'),
#  ('provinces', 'LOC'),
#  ('Tours', 'GPE'),
#  ('silk', 'PRODUCT'),
#  ('furniture', 'PRODUCT'),
#  ('Ganges', 'GPE'),
#  ('Cevennes', 'LOC'),
#  ('silk', 'PRODUCT'),
#  ('stockings', 'PRODUCT'),
#  ('Lyons', 'GPE'),
#  ('silk', 'PRODUCT'),
#  ('Paris', 'GPE'),
#  ('Lyons', 'GPE'),
#  ('181', 'DATE'),
#  ('45,500', 'MONEY'),
#  (',', 'MONEY'),
#  ('(', 'MONEY'),
#  ('HIO', 'MONEY'),
#  ('francs', 'MONEY'),
#  ('33,000,000', 'QUANTITY'),
#  ('silk', 'PRODUCT'),
#  ('manufactured', 'PRODUCT'),
#  ('goods', 'PRODUCT'),
#  ('cotton', 'PRODUCT'),
#  ('France', 'GPE'),
#  ('Cotton', 'PRODUCT'),
#  ('Alsace', 'GPE'),
#  ('England', 'GPE'),
#  ('11113', 'DATE'),
#  ('3,000', 'QUANTITY'),
#  ('kilogrammes', 'QUANTITY'),
#  ('oitton', 'PRODUCT'),
#  ('cambrics', 'PRODUCT'),
#  ('gaiue', 'PRODUCT'),
#  ('aiul', 'PRODUCT'),
#  ('lawn', 'PRODUCT'),
#  ('St', 'GPE'),
#  ('Quentin', 'GPE'),
#  ('Valen', 'GPE'),
#  ('-', 'GPE'),
#  ('ciennes', 'GPE'),
#  ('Cambray', 'GPE'),
#  ('Lace', 'PRODUCT'),
#  ('linen', 'PRODUCT'),
#  ('hemp', 'PRODUCT'),
#  ('300,00', 'MONEY'),
#  ('(', 'MONEY'),
#  ('»', 'MONEY'),
#  (',', 'MONEY'),
#  ('000', 'MONEY'),
#  ('francs', 'MONEY'),
#  ('1814', 'DATE'),
#  ('100,000,000', 'QUANTITY'),
#  ('kilogrammes', 'QUANTITY'),
#  ('1825', 'DATE'),
#  ('180,000,000', 'QUANTITY'),
#  ('Paris', 'GPE'),
#  ('38,000,000', 'MONEY'),
#  ('francs', 'MONEY'),
#  ('Paris', 'GPE'),
#  ('45,075,030', 'CARDINAL'),
#  ('1820', 'DATE'),
#  ('80,031,303', 'CARDINAL'),
#  ('1830', 'DATE'),
#  ('France', 'GPE'),
#  ('England', 'GPE'),
#  ('roads', 'FAC'),
#  ('canals', 'FAC'),
#  ('roads', 'FAC'),
#  ('England', 'GPE'),
#  ('cross', 'FAC'),
#  ('-', 'FAC'),
#  ('roeds', 'FAC'),
#  ('roads', 'FAC'),
#  ('canals', 'FAC'),
#  ('France', 'GPE'),
#  ('England', 'GPE'),
#  ('France', 'GPE'),
#  ('steam', 'FAC'),
#  ('.', 'FAC'),
#  ('engines', 'FAC'),
#  ('steam', 'FAC'),
#  ('-', 'FAC'),
#  ('engines', 'FAC'),
#  ('France', 'GPE'),
#  ('Dupin', 'PERSON'),
#  ('England', 'GPE'),
#  ('France', 'GPE'),
#  ('England', 'GPE'),
#  ('colonies', 'LOC'),
#  ('1788', 'DATE'),
#  ('337,0', 'MONEY'),
#  ('tW', 'MONEY'),
#  (',', 'MONEY'),
#  ("'", 'MONEY'),
#  ('i', 'MONEY'),
#  ('00', 'MONEY'),
#  ('francs', 'MONEY'),
#  ('1834', 'DATE'),
#  ('50,000,000', 'MONEY'),
#  ('France', 'GPE'),
#  ('1834', 'DATE'),
#  ('440,543,000', 'MONEY'),
#  ('francs', 'MONEY'),
#  ('103,050,000', 'MONEY'),
#  ('277,486,000', 'MONEY'),
#  ('manufactured', 'PRODUCT'),
#  ('United', 'GPE'),
#  ('States', 'GPE'),
#  ('55,000,000', 'MONEY'),
#  ('454,801,000', 'MONEY'),
#  ('francs', 'MONEY'),
#  ('373,873,000', 'MONEY'),
#  ('materials', 'PRODUCT'),
#  ('for', 'PRODUCT'),
#  ('manufacture', 'PRODUCT'),
#  ('natural', 'PRODUCT'),
#  ('productions', 'PRODUCT'),
#  ('for', 'PRODUCT'),
#  ('consumption', 'PRODUCT'),
#  ('manufactured', 'PRODUCT'),
#  ('articles', 'PRODUCT'),
#  ('1824', 'DATE'),
#  ('ships', 'FAC'),
#  ('328,480', 'CARDINAL'),
#  ('28,040', 'CARDINAL'),
#  ('47,383', 'CARDINAL'),
#  ('fisheries', 'FAC'),
#  ('navy', 'NORP'),
#  ('1838', 'DATE'),
#  ('38', 'CARDINAL'),
#  ('ships', 'FAC'),
#  ('35', 'CARDINAL'),
#  ('frigates', 'FAC'),
#  ('8', 'CARDINAL'),
#  ('steam', 'FAC'),
#  ('186', 'CARDINAL'),
#  ('veasels', 'FAC'),
#  ('14,003', 'CARDINAL'),
#  ('officera', 'NORP'),
#  ('sailors', 'NORP'),
#  ('army', 'NORP'),
#  ('1828 am', 'DATE'),
#  ('233,770', 'CARDINAL'),
#  ('French', 'NORP'),
#  ('-', 'NORP'),
#  ('man', 'NORP'),
#  ('1828', 'DATE'),
#  ('l', 'MONEY'),
#  (',', 'MONEY'),
#  ('037', 'MONEY'),
#  (',', 'MONEY'),
#  ('iO', 'MONEY'),
#  ('4,4', 'MONEY'),
#  ('»', 'MONEY'),
#  ('l', 'MONEY'),
#  ('francs', 'MONEY'),
#  ('1,035,415,552', 'MONEY'),
#  ('franos', 'MONEY'),
#  ('French', 'EVENT'),
#  ('Revo', 'EVENT'),
#  ('-', 'EVENT'),
#  ('lution', 'EVENT'),
#  ('1780', 'DATE'),
#  ('military', 'NORP'),
#  ('nation', 'NORP'),
#  ('manufac', 'FAC'),
#  ('-', 'FAC'),
#  ('tures', 'FAC'),
#  ('constitution', 'LAW'),
#  ('1830', 'DATE'),
#  ('Louis', 'PERSON'),
#  ('Philip', 'PERSON'),
#  ('throne', 'NORP'),
#  ('three', 'EVENT'),
#  ('days', 'EVENT'),
#  ('revolu', 'EVENT'),
#  ('-', 'EVENT'),
#  ('tion', 'EVENT'),
#  ('Bourbons', 'NORP'),
#  ('house', 'NORP'),
#  ('of', 'NORP'),
#  ('Orleans', 'NORP'),
#  ('Louis', 'PERSON'),
#  ('XIV', 'PERSON'),
#  ('Philip', 'PERSON'),
#  ('Duke', 'PERSON'),
#  ('of', 'PERSON'),
#  ('Orleans', 'PERSON'),
#  ('France', 'GPE'),
#  ('Capet', 'PERSON'),
#  ('Dyruuty', 'PERSON'),
#  ('Hugh', 'PERSON'),
#  ('Capet', 'PERSON'),
#  ('987', 'DATE'),
#  ('900', 'DATE'),
#  ('Robert', 'PERSON'),
#  ('031', 'DATE'),
#  ('Henry', 'PERSON'),
#  ('L', 'PERSON'),
#  ('1080', 'DATE'),
#  ('Philip', 'PERSON'),
#  ('L', 'PERSON'),
#  ('1108', 'DATE'),
#  ('L', 'PERSON'),
#  ('uis', 'PERSON'),
#  ('IV', 'PERSON'),
#  ('113', 'DATE'),
#  ('?', 'DATE'),
#  ('liouis', 'PERSON'),
#  ('Vn', 'PERSON'),
#  ('Philip', 'PERSON'),
#  ('il', 'PERSON'),
#  ('.', 'PERSON'),
#  ('Augustus', 'PERSON'),
#  ('1233', 'DATE'),
#  ('Louis', 'PERSON'),
#  ('VIII', 'PERSON'),
#  ('1336', 'DATE'),
#  ('Louis', 'PERSON'),
#  ('IX', 'PERSON'),
#  ('.', 'PERSON'),
#  ('(', 'PERSON'),
#  ('the', 'PERSON'),
#  ('Saint', 'PERSON'),
#  (')', 'PERSON'),
#  ('1370', 'DATE'),
#  ('Philip', 'PERSON'),
#  ('III', 'PERSON'),
#  ('.', 'PERSON'),
#  ('(', 'PERSON'),
#  ('the', 'PERSON'),
#  ('Bold', 'PERSON'),
#  (')', 'PERSON'),
#  ('1285', 'DATE'),
#  ('Philip', 'PERSON'),
#  ('IV', 'PERSON'),
#  ('.', 'PERSON'),
#  ('(', 'PERSON'),
#  ('the', 'PERSON'),
#  ('Fair', 'PERSON'),
#  (')', 'PERSON'),
#  ('1314', 'DATE'),
#  ('Louts', 'PERSON'),
#  ('X', 'PERSON'),
#  ('.', 'PERSON'),
#  ('(', 'PERSON'),
#  ('Hutin', 'PERSON'),
#  (')', 'PERSON'),
#  ('1310', 'DATE'),
#  ('Philip', 'PERSON'),
#  ('V', 'PERSON'),
#  ('.', 'PERSON'),
#  ('(', 'PERSON'),
#  ('the', 'PERSON'),
#  ('liong', 'PERSON'),
#  (')', 'PERSON'),
#  ('1331', 'DATE'),
#  ('Charles', 'PERSON'),
#  ('IV', 'PERSON'),
#  ('.', 'PERSON'),
#  ('(', 'PERSON'),
#  ('the', 'PERSON'),
#  ('Fair', 'PERSON'),
#  (')', 'PERSON'),
#  ('133', 'DATE'),
#  ('a', 'DATE'),
#  ('—', 'DATE'),
#  ('3', 'DATE'),
#  ('Branch', 'PERSON'),
#  ('0', 'PERSON'),
#  ('/', 'PERSON'),
#  ('Vahitt', 'PERSON'),
#  ('Philip', 'PERSON'),
#  ('VL', 'PERSON'),
#  ('1350', 'DATE'),
#  ('John', 'PERSON'),
#  ('ChaHee', 'PERSON'),
#  ('V', 'PERSON'),
#  ('.', 'PERSON'),
#  ('(', 'PERSON'),
#  ('the', 'PERSON'),
#  ('Wise', 'PERSON'),
#  (')', 'PERSON'),
#  ('1380', 'DATE'),
#  ('Charles', 'PERSON'),
#  ('VI', 'PERSON'),
#  ('1433', 'DATE'),
#  ('Charles', 'PERSON'),
#  ('VIL', 'PERSON'),
#  ('1401', 'DATE'),
#  ('Louis', 'PERSON'),
#  ('XI', 'PERSON'),
#  ('1463', 'DATE'),
#  ('Charles', 'PERSON'),
#  ('VIIL', 'PERSON'),
#  ('1407', 'DATE'),
#  ('Louis', 'PERSON'),
#  ('XIL', 'PERSON'),
#  ('1515', 'DATE'),
#  ('Francis', 'PERSON'),
#  ('I', 'PERSON'),
#  ('1547', 'DATE'),
#  ('Henry', 'PERSON'),
#  ('IL', 'PERSON'),
#  ('1550', 'DATE'),
#  ('1560', 'DATE'),
#  ('Charles', 'PERSON'),
#  ('IX', 'PERSON'),
#  ('1574', 'DATE'),
#  ('Henry', 'PERSON'),
#  ('IIL', 'PERSON'),
#  ('1580', 'DATE'),
#  ('Henry', 'PERSON'),
#  ('IV', 'PERSON'),
#  ('1610', 'DATE'),
#  ('Louis', 'PERSON'),
#  ('XIIL', 'PERSON'),
#  ('1643', 'DATE'),
#  ('LoiHs', 'PERSON'),
#  ('XIV', 'PERSON'),
#  ('1715', 'DATE'),
#  ('Louis', 'PERSON'),
#  ('XV', 'PERSON'),
#  ('Louis', 'PERSON'),
#  ('XVI', 'PERSON'),
#  ('1793', 'DATE'),
#  ('Louis', 'PERSON'),
#  ('XVU', 'PERSON'),
#  ('French', 'NORP'),
#  ('republic', 'NORP'),
#  ('1703', 'DATE'),
#  ('1804', 'DATE'),
#  ('Napoleon', 'PERSON'),
#  ('Emperor', 'NORP'),
#  ('of', 'NORP'),
#  ('the', 'NORP'),
#  ('French', 'NORP'),
#  ('1804', 'DATE'),
#  ('1814', 'DATE'),
#  ('Louis', 'PERSON'),
#  ('XVIIL', 'PERSON'),
#  ('1814', 'DATE'),
#  ('1024', 'DATE'),
#  ('Charles', 'PERSON'),
#  ('1830', 'DATE'),
#  ('House', 'NORP'),
#  ('of', 'NORP'),
#  ('Orleans', 'NORP'),
#  ('Louis', 'PERSON'),
#  ('Philip', 'PERSON'),
#  ('King', 'NORP'),
#  ('of', 'NORP'),
#  ('the', 'NORP'),
#  ('French', 'NORP'),
#  ('Bourbon', 'NORP'),
#  ('family', 'NORP'),
#  ('Charles', 'PERSON'),
#  ('X', 'PERSON'),
#  ('Louis', 'PERSON'),
#  ('Antoine', 'PERSON'),
#  (',', 'PERSON'),
#  ('Duke', 'PERSON'),
#  ('of', 'PERSON'),
#  ('Angouldme', 'PERSON'),
#  ('(', 'PERSON'),
#  ('late', 'PERSON'),
#  ('dauphin', 'PERSON'),
#  (')', 'PERSON'),
#  ('August', 'DATE'),
#  ('6', 'DATE'),
#  (',', 'DATE'),
#  ('1775', 'DATE'),
#  ('Marie', 'PERSON'),
#  ('Therese', 'PERSON'),
#  ('Louie', 'PERSON'),
#  ('XVI', 'PERSON'),
#  ('Charles', 'PERSON'),
#  ('X', 'PERSON'),
#  ('.', 'PERSON'),
#  (',', 'PERSON'),
#  ('Duke', 'PERSON'),
#  ('of', 'PERSON'),
#  ('Berry', 'PERSON'),
#  ('Jan', 'DATE'),
#  ('.', 'DATE'),
#  ('24', 'DATE'),
#  (',', 'DATE'),
#  ('1778', 'DATE'),
#  ('Caroline', 'PERSON'),
#  (',', 'PERSON'),
#  ('Princess', 'PERSON'),
#  ('of', 'PERSON'),
#  ('Naples', 'PERSON'),
#  ('Nov', 'DATE'),
#  ('.', 'DATE'),
#  ('5', 'DATE'),
#  (',', 'DATE'),
#  ('1708', 'DATE'),
#  ('Louvain', 'PERSON'),
#  ('Feb', 'DATE'),
#  (',', 'DATE'),
#  ('14', 'DATE'),
#  (',', 'DATE'),
#  ('1820', 'DATE'),
#  ('Maria', 'PERSON'),
#  ('Louise', 'PERSON'),
#  ('(', 'PERSON'),
#  ('Mile', 'PERSON'),
#  ('.', 'PERSON'),
#  ('d', 'PERSON'),
#  ('*', 'PERSON'),
#  ('Artois', 'PERSON'),
#  (',', 'PERSON'),
#  ('Sept', 'DATE'),
#  ('.', 'DATE'),
#  ('21', 'DATE'),
#  (',', 'DATE'),
#  ('1819', 'DATE'),
#  ('Henry', 'PERSON'),
#  ('(', 'PERSON'),
#  ('Charles', 'PERSON'),
#  ('Ferdinrnd', 'PERSON'),
#  ('Marie', 'PERSON'),
#  ("DieudonnL'", 'PERSON'),
#  (')', 'PERSON'),
#  ('Duke', 'PERSON'),
#  ('1820', 'DATE'),
#  ('Charles', 'PERSON'),
#  ('Kiag', 'PERSON'),
#  ('Henry', 'PERSON'),
#  ('V', 'PERSON'),
#  ('I', 'PERSON'),
#  ('<', 'PERSON'),
#  ('ouis', 'PERSON'),
#  ('Philip', 'PERSON'),
#  ('Ferdinand', 'PERSON'),
#  ('PhtUp', 'PERSON'),
#  ('Louis', 'PERSON'),
#  ('Charles', 'PERSON'),
#  ('Henry', 'PERSON'),
#  ('Duke', 'PERSON'),
#  ('of', 'PERSON'),
#  ('Orleans', 'PERSON'),
#  ('1810', 'DATE')]

# %%
spacy_annotations = [(ent.text, ent.label_) for ent in doc.ents]

# %%
print(f'Spacy Annotations List number = {len(spacy_annotations)}')
spacy_annotations
# Out:
# Spacy Annotations List number = 294
# [('France', 'GPE'),
#  ('1', 'CARDINAL'),
#  ('The \n Toeget', 'ORG'),
#  ('2', 'CARDINAL'),
#  ('0000 \n feet', 'QUANTITY'),
#  ('3', 'CARDINAL'),
#  ('Alpine', 'ORG'),
#  ('Daaphlny \n ', 'ORG'),
#  ('Provence', 'GPE'),
#  ('4', 'CARDINAL'),
#  ('Auvergne', 'GPE'),
#  ('the Puy de Dome', 'FAC'),
#  ('the \n Cental', 'ORG'),
#  ('5', 'CARDINAL'),
#  ('0', 'CARDINAL'),
#  ('France', 'GPE'),
#  ('Spain', 'GPE'),
#  ('four', 'CARDINAL'),
#  ('Rhine', 'GPE'),
#  ('Seine', 'PERSON'),
#  ('Loire', 'ORG'),
#  ('the \n Garonne', 'LOC'),
#  ('Marne', 'PERSON'),
#  ('Oise', 'PERSON'),
#  ('Seine', 'PERSON'),
#  ('Loire', 'ORG'),
#  ('Maycnne', 'PERSON'),
#  ('Loire', 'ORG'),
#  ('Rhone', 'ORG'),
#  ('Saoue', 'ORG'),
#  ('Durance', 'ORG'),
#  ('Ain', 'PERSON'),
#  ('Garonne', 'LOC'),
#  ('France', 'GPE'),
#  ('Normandy', 'PERSON'),
#  ('the Isle \n of', 'ORG'),
#  ('France', 'GPE'),
#  ('about \n 18,I70,51>0 acres', 'QUANTITY'),
#  ('7)054,501 acres', 'QUANTITY'),
#  ('Languedoc', 'ORG'),
#  ('Limarne', 'PERSON'),
#  ('Auvergne', 'GPE'),
#  ('one', 'CARDINAL'),
#  ('twenty feet', 'QUANTITY'),
#  ('Tlie \n ', 'PERSON'),
#  ('Bretagne', 'GPE'),
#  ('Anjou', 'GPE'),
#  ('Maine', 'GPE'),
#  ('Junipers', 'ORG'),
#  ('twenty', 'CARDINAL'),
#  ('twelve', 'CARDINAL'),
#  ('10,795,000 \n acres', 'QUANTITY'),
#  ('Ardennes', 'NORP'),
#  ('Orleans', 'ORG'),
#  ("For.taincl'leau", 'ORG'),
#  ('Mediterranean', 'LOC'),
#  ('Languedoc', 'PERSON'),
#  ('Provence', 'GPE'),
#  ('half', 'CARDINAL'),
#  ('eM', 'ORG'),
#  ('France', 'GPE'),
#  ('Dupin', 'PERSON'),
#  ('53,533,430', 'CARDINAL'),
#  ('139,094,000 English acres', 'QUANTITY'),
#  ('annual', 'DATE'),
#  ('31 per cent', 'MONEY'),
#  ('eighteen \n bushels', 'QUANTITY'),
#  ('English', 'LANGUAGE'),
#  ('1813', 'DATE'),
#  ('France', 'GPE'),
#  ('9,170,000', 'CARDINAL'),
#  ('1810', 'DATE'),
#  ('1', 'CARDINAL'),
#  ('2,500,000', 'CARDINAL'),
#  ('6,073,000 1', 'CARDINAL'),
#  ('about \n 45,0e^000', 'CARDINAL'),
#  ('about 51,600,000', 'CARDINAL'),
#  ('French', 'NORP'),
#  ('Champagne', 'ORG'),
#  ('Burgundy', 'PERSON'),
#  ('France', 'GPE'),
#  ('about 800,000,000', 'CARDINAL'),
#  ('M. Dupin', 'PERSON'),
#  ('3', 'CARDINAL'),
#  ('01', 'CARDINAL'),
#  ('more than \n ', 'CARDINAL'),
#  ('third', 'ORDINAL'),
#  ('France', 'GPE'),
#  ('France', 'GPE'),
#  ('Sedan', 'NORP'),
#  ('M. Chaptal', 'ORG'),
#  ('English', 'NORP'),
#  ('French', 'NORP'),
#  ('38,000,000 kilogrammes', 'QUANTITY'),
#  ('about 3|lbs', 'CARDINAL'),
#  ('1836', 'DATE'),
#  ('4^,000,000', 'CARDINAL'),
#  ('305,000,000 francs', 'MONEY'),
#  ('105,000,000', 'CARDINAL'),
#  ('about one-thirteenth', 'CARDINAL'),
#  ('Tours', 'GPE'),
#  ('Ganges', 'ORG'),
#  ('Cevennes', 'ORG'),
#  ('Paris \n ', 'ORG'),
#  ('181', 'CARDINAL'),
#  ('45,500,(HIO francs', 'MONEY'),
#  ('less than one-third', 'CARDINAL'),
#  ('Forty years ago', 'DATE'),
#  ('France', 'GPE'),
#  ('Cotton \n ', 'PERSON'),
#  ('Alsace', 'ORG'),
#  ('11113', 'DATE'),
#  ('1H2A', 'CARDINAL'),
#  ('St Quentin', 'PERSON'),
#  ('Cambray', 'PERSON'),
#  ('French Industry', 'ORG'),
#  ('Lace', 'PERSON'),
#  ('300,00(»,000 francs', 'MONEY'),
#  ('100,000,000 kilogrammes', 'QUANTITY'),
#  ('1825', 'DATE'),
#  ('180,000,000', 'CARDINAL'),
#  ('Paris', 'GPE'),
#  ('annual', 'DATE'),
#  ('Paris', 'GPE'),
#  ('IRU', 'ORG'),
#  ('45,075,030', 'CARDINAL'),
#  ('1820', 'DATE'),
#  ('1830', 'DATE'),
#  ('144,58I,(MI4', 'CARDINAL'),
#  ('NotwJth', 'PERSON'),
#  ('France', 'GPE'),
#  ('One', 'CARDINAL'),
#  ('France \n ', 'ORG'),
#  ('more than one-third', 'CARDINAL'),
#  ('France', 'GPE'),
#  ('England', 'GPE'),
#  ('France', 'GPE'),
#  ('dlHiculty', 'ORG'),
#  ('France', 'GPE'),
#  ('Dupin', 'ORG'),
#  ('England', 'GPE'),
#  ('France', 'GPE'),
#  ('tinly one-fourth', 'CARDINAL'),
#  ('England', 'GPE'),
#  ('France', 'GPE'),
#  ('colonies', 'GPE'),
#  ('1788', 'DATE'),
#  ("337,0tW,'i00 francs", 'MONEY'),
#  ('1834', 'DATE'),
#  ('only 50,000,000', 'CARDINAL'),
#  ('France', 'GPE'),
#  ('1834', 'DATE'),
#  ('440,543,000 francs', 'MONEY'),
#  ('103,050,000', 'CARDINAL'),
#  ('277,486,000', 'CARDINAL'),
#  ('the United States', 'GPE'),
#  ('55,000,000', 'CARDINAL'),
#  ('the same year', 'DATE'),
#  ('454,801,000 francs', 'MONEY'),
#  ('373,873,000', 'CARDINAL'),
#  ('121', 'CARDINAL'),
#  ('9r)7,000', 'CARDINAL'),
#  ('1824', 'DATE'),
#  ('French', 'NORP'),
#  ('328,480', 'CARDINAL'),
#  ('28,040', 'CARDINAL'),
#  ('47,383', 'CARDINAL'),
#  ('1838', 'DATE'),
#  ('38', 'CARDINAL'),
#  ('35', 'CARDINAL'),
#  ('8 steam.boaU', 'CARDINAL'),
#  ('186', 'CARDINAL'),
#  ('14,003', 'CARDINAL'),
#  ('233,770', 'CARDINAL'),
#  ('annual', 'DATE'),
#  ('twenty years', 'DATE'),
#  ('eight years', 'DATE'),
#  ('1828', 'DATE'),
#  ('French', 'NORP'),
#  ('1780', 'DATE'),
#  ('9', 'CARDINAL'),
#  ('one', 'CARDINAL'),
#  ('France', 'GPE'),
#  ('the constitution \n ', 'LAW'),
#  ('1830', 'DATE'),
#  ('Louis Philip', 'PERSON'),
#  ('three days', 'DATE'),
#  ('Orleans', 'ORG'),
#  ('^e', 'ORG'),
#  ('Louis XIV.', 'PERSON'),
#  ('Philip Duke', 'PERSON'),
#  ('France', 'GPE'),
#  ('1', 'CARDINAL'),
#  ('Hugh Capet \n ', 'ORG'),
#  ('987', 'CARDINAL'),
#  ('Robert', 'PERSON'),
#  ('031', 'CARDINAL'),
#  ('Henry L', 'PERSON'),
#  ('Philip L', 'ORG'),
#  ('1108', 'DATE'),
#  ('113', 'CARDINAL'),
#  ('1180', 'DATE'),
#  ('Philip', 'PERSON'),
#  ('Louis VIII', 'PERSON'),
#  ('1336', 'DATE'),
#  ('Louis IX', 'PERSON'),
#  ('Saint', 'GPE'),
#  ('1370', 'DATE'),
#  ('Philip III', 'PERSON'),
#  ('1285', 'DATE'),
#  ('Philip \n \n IV', 'PERSON'),
#  ('Fair', 'ORG'),
#  ('1314', 'DATE'),
#  ('Hutin', 'LOC'),
#  ('Philip V.', 'PERSON'),
#  ('1331', 'DATE'),
#  ('Charles IV', 'PERSON'),
#  ('Fair', 'ORG'),
#  ('133a', 'CARDINAL'),
#  ('3', 'CARDINAL'),
#  ('Vahitt Philip \n VL', 'PERSON'),
#  ('1350', 'DATE'),
#  ('John', 'PERSON'),
#  ('VMA', 'ORG'),
#  ('ChaHee \n \n V.', 'PERSON'),
#  ('1380', 'DATE'),
#  ('Charles VI', 'PERSON'),
#  ('1433', 'DATE'),
#  ('Charles VIL', 'PERSON'),
#  ('1401', 'DATE'),
#  ('Louis XI', 'PERSON'),
#  ('1463', 'DATE'),
#  ('Charles VIIL', 'PERSON'),
#  ('1407 3', 'DATE'),
#  ('1515', 'DATE'),
#  ('Francis I.', 'PERSON'),
#  ('1547', 'DATE'),
#  ('Henry \n IL', 'ORG'),
#  ('1550', 'DATE'),
#  ('Francis IL', 'PERSON'),
#  ('1560', 'DATE'),
#  ('Charles IX.', 'PERSON'),
#  ('1574', 'DATE'),
#  ('Henry IIL', 'ORG'),
#  ('1580', 'DATE'),
#  ('4', 'CARDINAL'),
#  ('Henry IV', 'PERSON'),
#  ('1610', 'CARDINAL'),
#  ('Louis XIIL', 'PERSON'),
#  ('LoiHs XIV', 'PERSON'),
#  ('1715', 'DATE'),
#  ('Louis XV', 'PERSON'),
#  ('1774', 'DATE'),
#  ('Louis XVI', 'PERSON'),
#  ('1793', 'CARDINAL'),
#  ('Louis XVU', 'PERSON'),
#  ('17!»6', 'CARDINAL'),
#  ('French', 'NORP'),
#  ('1703 to 1804', 'DATE'),
#  ('Napoleon', 'ORG'),
#  ('French', 'NORP'),
#  ('1804 to 1814', 'DATE'),
#  ('Louis XVIIL', 'PERSON'),
#  ('1814', 'DATE'),
#  ('1024', 'DATE'),
#  ('Charles', 'PERSON'),
#  ('1830', 'DATE'),
#  ('\\ew House of Orleans', 'ORG'),
#  ('Louis Philip \n I.', 'PERSON'),
#  ('French', 'NORP'),
#  ('Charles X.', 'PERSON'),
#  ('Louis Antoine', 'PERSON'),
#  ('August 6, 1775', 'DATE'),
#  ('Marie Therese', 'PERSON'),
#  ('Louie \n XVI', 'PERSON'),
#  ('second', 'ORDINAL'),
#  ('Charles X.', 'PERSON'),
#  ('Jan. 24, 1778', 'DATE'),
#  ('Caroline', 'PERSON'),
#  ('Nov. 5, 1708', 'DATE'),
#  ('14, 1820', 'DATE'),
#  ('Maria \n Louise', 'PERSON'),
#  ('Mile', 'PERSON'),
#  ('Sept. 21, 1819', 'DATE'),
#  ('Charles Ferdinrnd Marie', 'PERSON'),
#  ('Bordeaux', 'PERSON'),
#  ('Kept', 'ORG'),
#  ('20, 1820', 'DATE'),
#  ('Kiag \n Henry V. I<ouis', 'PERSON'),
#  ('Philip', 'PERSON'),
#  ('five', 'CARDINAL'),
#  ('Charles Henry', 'PERSON'),
#  ('Duke of Orleans', 'ORG'),
#  ('1810', 'DATE')]

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

y_true = [label for token, label in hand_annotated_clean]
y_pred = [label for token, label in spacy_annotations]



# Calculate precision, recall, and F1-score for each label

precision = precision_score(y_true, y_pred, average='weighted')
recall = recall_score(y_true, y_pred, average='weighted')
f1 = f1_score(y_true, y_pred, average='weighted')

print(f"Label: {label}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1-score: {f1}")
print()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/owenmonroe/Desktop/GitHub/TextMiningFall23/Progress_Report/NER_Progress_Study.ipynb Cell 14 line 1
#       <a href='vscode-notebook-cell:/Users/owenmonroe/Desktop/GitHub/TextMiningFall23/Progress_Report/NER_Progress_Study.ipynb#X12sZmlsZQ%3D%3D?line=3'>4</a> y_pred = [label for token, label in spacy_annotations]
#       <a href='vscode-notebook-cell:/Users/owenmonroe/Desktop/GitHub/TextMiningFall23/Progress_Report/NER_Progress_Study.ipynb#X12sZmlsZQ%3D%3D?line=7'>8</a> # Calculate precision, recall, and F1-score for each label
# ---> <a href='vscode-notebook-cell:/Users/owenmonroe/Desktop/GitHub/TextMiningFall23/Progress_Report/NER_Progress_Study.ipynb#X12sZmlsZQ%3D%3D?line=9'>10</a> precision = precision_score(y_true, y_pred, average='weighted')
#      <a href='vscode-notebook-cell:/Users/owenmonroe/Desktop/GitHub/TextMiningFall23/Progress_Report/NER_Progress_Study.ipynb#X12sZmlsZQ%3D%3D?line=10'>11</a> recall = recall_score(y_true, y_pred, average='weighted')
#      <a href='vscode-notebook-cell:/Users/owenmonroe/Desktop/GitHub/TextMiningFall23/Progress_Report/NER_Progress_Study.ipynb#X12sZmlsZQ%3D%3D?line=11'>12</a> f1 = f1_score(y_true, y_pred, average='weighted')
#
# File ~/anaconda3/envs/textmining/lib/python3.8/site-packages/sklearn/utils/_param_validation.py:214, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     208 try:
#     209     with config_context(
#     210         skip_parameter_validation=(
#     211             prefer_skip_nested_validation or global_skip_validation
#     212         )
#     213     ):
# --> 214         return func(*args, **kwargs)
#     215 except InvalidParameterError as e:
#     216     # When the function is just a wrapper around an estimator, we allow
#     217     # the function to delegate validation to the estimator, but we replace
#     218     # the name of the estimator by the name of the function in the error
#     219     # message to avoid confusion.
#     220     msg = re.sub(
#     221         r"parameter of \w+ must be",
#     222         f"parameter of {func.__qualname__} must be",
#     223         str(e),
#     224     )
#
# File ~/anaconda3/envs/textmining/lib/python3.8/site-packages/sklearn/metrics/_classification.py:2131, in precision_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    1973 @validate_params(
#    1974     {
#    1975         "y_true": ["array-like", "sparse matrix"],
#    (...)
#    2000     zero_division="warn",
#    2001 ):
#    2002     """Compute the precision.
#    2003
#    2004     The precision is the ratio ``tp / (tp + fp)`` where ``tp`` is the number of
#    (...)
#    2129     array([0.5, 1. , 1. ])
#    2130     """
# -> 2131     p, _, _, _ = precision_recall_fscore_support(
#    2132         y_true,
#    2133         y_pred,
#    2134         labels=labels,
#    2135         pos_label=pos_label,
#    2136         average=average,
#    2137         warn_for=("precision",),
#    2138         sample_weight=sample_weight,
#    2139         zero_division=zero_division,
#    2140     )
#    2141     return p
#
# File ~/anaconda3/envs/textmining/lib/python3.8/site-packages/sklearn/utils/_param_validation.py:187, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     185 global_skip_validation = get_config()["skip_parameter_validation"]
#     186 if global_skip_validation:
# --> 187     return func(*args, **kwargs)
#     189 func_sig = signature(func)
#     191 # Map *args/**kwargs to the function signature
#
# File ~/anaconda3/envs/textmining/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1724, in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1566 """Compute precision, recall, F-measure and support for each class.
#    1567
#    1568 The precision is the ratio ``tp / (tp + fp)`` where ``tp`` is the number of
#    (...)
#    1721  array([2, 2, 2]))
#    1722 """
#    1723 zero_division_value = _check_zero_division(zero_division)
# -> 1724 labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1726 # Calculate tp_sum, pred_sum, true_sum ###
#    1727 samplewise = average == "samples"
#
# File ~/anaconda3/envs/textmining/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1501, in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1498 if average not in average_options and average != "binary":
#    1499     raise ValueError("average has to be one of " + str(average_options))
# -> 1501 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    1502 # Convert to Python primitive type to avoid NumPy type / Python str
#    1503 # comparison. See https://github.com/numpy/numpy/issues/6784
#    1504 present_labels = unique_labels(y_true, y_pred).tolist()
#
# File ~/anaconda3/envs/textmining/lib/python3.8/site-packages/sklearn/metrics/_classification.py:84, in _check_targets(y_true, y_pred)
#      57 def _check_targets(y_true, y_pred):
#      58     """Check that y_true and y_pred belong to the same classification task.
#      59
#      60     This converts multiclass or binary types to a common shape, and raises a
#    (...)
#      82     y_pred : array or indicator matrix
#      83     """
# ---> 84     check_consistent_length(y_true, y_pred)
#      85     type_true = type_of_target(y_true, input_name="y_true")
#      86     type_pred = type_of_target(y_pred, input_name="y_pred")
#
# File ~/anaconda3/envs/textmining/lib/python3.8/site-packages/sklearn/utils/validation.py:407, in check_consistent_length(*arrays)
#     405 uniques = np.unique(lengths)
#     406 if len(uniques) > 1:
# --> 407     raise ValueError(
#     408         "Found input variables with inconsistent numbers of samples: %r"
#     409         % [int(l) for l in lengths]
#     410     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [645, 294]
